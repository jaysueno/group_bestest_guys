# %%
import pandas as pd
import numpy as np

# %%
stocks_daily = pd.read_csv('data/gspc_daily_clean.csv')

# %%
stocks_daily
# Out:
#             Date         Open        Close     Change  % Change Up/Down
# 0     2016-11-08  2129.919922  2139.560059   9.640137  0.004526      up
# 1     2016-11-09  2131.560059  2163.260010  31.699951  0.014872      up
# 2     2016-11-10  2167.489990  2167.479980  -0.010010 -0.000005    down
# 3     2016-11-11  2162.709961  2164.449951   1.739990  0.000805      up
# 4     2016-11-14  2165.639893  2164.199951  -1.439942 -0.000665    down
# ...          ...          ...          ...        ...       ...     ...
# 997   2020-10-26  3441.419922  3400.969971 -40.449951 -0.011754    down
# 998   2020-10-27  3403.149902  3390.679932 -12.469970 -0.003664    down
# 999   2020-10-28  3342.479980  3271.030029 -71.449951 -0.021376    down
# 1000  2020-10-29  3277.169922  3310.110107  32.940185  0.010051      up
# 1001  2020-10-30  3293.590088  3269.959961 -23.630127 -0.007175    down
#
# [1002 rows x 6 columns]
