# %% [markdown]
# ## Install and Updated Required Libraries

# %%
### Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
### install joblib. This will be used to save your model. 
### Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv('../data/daily_summary.csv')
df = df.dropna(axis='columns', how='all')
df = df.drop('index', axis=1)
df
# Out:
#            date  tweets  isRetweet  isDeleted  avg_sentiment_score  \
# 0    2016-11-08      17          4          0             5.855472
# 1    2016-11-09       3          1          0             5.599524
# 2    2016-11-10       1          0          0             6.650000
# 3    2016-11-11       5          0          0             5.826134
# 4    2016-11-15       2          0          0             5.873654
# ..          ...     ...        ...        ...                  ...
# 986  2020-10-19      27          6          0             5.663288
# 987  2020-10-20       8          0          0             5.668879
# 988  2020-10-21      37          5          0             5.512343
# 989  2020-10-22      26          1          0             5.583342
# 990  2020-10-23      48         27          0             5.559891
#
#      sum_sentiment_score  delta_avg  retweets  favorites  word_count  \
# 0                 915.44   0.099388    522435    1118266         908
# 1                 156.98  -0.156560    227982     700580         163
# 2                  39.90   0.893916     36535     142625          32
# 3                 355.76   0.070050    193625     832596         351
# 4                 146.84   0.117570     69857     254719         144
# ..                   ...        ...       ...        ...         ...
# 986              1729.56  -0.092796    616069    2462718        1799
# 987               421.14  -0.087205    301467    1293019         437
# 988              2379.17  -0.243741    646224    2554907        2529
# 989              2050.85  -0.172742    681597    3209931        2118
# 990              1906.58  -0.196193   1115660    3068584        2028
#
#      positive  negative  neutral  s&p_%change s&p_up/down
# 0          12         0        4     0.004526          up
# 1           2         0        1     0.014872          up
# 2           1         0        0    -0.000005        down
# 3           4         0        1     0.000805          up
# 4           2         0        0     0.005580          up
# ..        ...       ...      ...          ...         ...
# 986        15         3        7    -0.019103        down
# 987         6         0        1     0.001087          up
# 988        18         4       10    -0.001265        down
# 989        16         2        8     0.004359          up
# 990        20         6       12     0.000141          up
#
# [991 rows x 15 columns]

# %% [markdown]
# ## Select Your Features(Columns)

# %%
selected_features = df.drop(['date', ])
