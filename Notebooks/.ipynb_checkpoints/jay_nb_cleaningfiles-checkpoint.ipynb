# %%
import pandas as pd 
import numpy as np

# %%
tweet_df = pd.read_csv('../data/trump_tweets_jay.csv')
hedo_df = pd.read_csv('../data/word_sentiment_rating.csv')
tweet_df_scores = pd.read_csv('../data/tweet_df_cleaned.csv')
tweet_df2 = pd.read_csv('../data/tweet_df_cleaned_w_sentiment.csv')

# %% [markdown]
# ## Tweet dataframe

# %%
# check for content and shape
tweet_df.isin
# Out:
#                         id                                               text  \
# 0        98454970654916608  Republicans and Democrats have both created ou...
# 1      1234653427789070336  I was thrilled to be back in the Great city of...
# 2      1218010753434820614  RT @CBS_Herridge: READ: Letter to surveillance...
# 3      1304875170860015617  The Unsolicited Mail In Ballot Scam is a major...
# 4      1218159531554897920  RT @MZHemingway: Very friendly telling of even...
# ...                    ...                                                ...
# 54437  1319484210101379072  RT @EliseStefanik: President @realDonaldTrump ...
# 54438  1319444420861829121  RT @TeamTrump: LIVE: Presidential Debate #Deba...
# 54439  1319384118849949702  Just signed an order to support the workers of...
# 54440  1319345719829008387  Suburban women want Safety &amp; Security. Joe...
# 54441  1319339440867741696  Just left the White House for the Great State ...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 0             f         f           TweetDeck         49       255
# 1             f         f  Twitter for iPhone      73748     17404
# 2             t         f  Twitter for iPhone          0      7396
# 3             f         f  Twitter for iPhone      80527     23502
# 4             t         f  Twitter for iPhone          0      9081
# ...         ...       ...                 ...        ...       ...
# 54437         t         f  Twitter for iPhone          0      9912
# 54438         t         f  Twitter for iPhone          0      8249
# 54439         f         f  Twitter for iPhone     175950     36098
# 54440         f         f  Twitter for iPhone      95325     19639
# 54441         f         f  Twitter for iPhone     137363     20791
#
#                       date
# 0      2011-08-02 18:07:48
# 1      2020-03-03 01:34:50
# 2      2020-01-17 03:22:47
# 3      2020-09-12 20:10:58
# 4      2020-01-17 13:13:59
# ...                    ...
# 54437  2020-10-23 03:42:05
# 54438  2020-10-23 01:03:58
# 54439  2020-10-22 21:04:21
# 54440  2020-10-22 18:31:46
# 54441  2020-10-22 18:06:49
#
# [54442 rows x 8 columns]

# %%
# compare tweet list with no re-tweets
no_retweets = tweet_df['isRetweet'] == 'f'
tweet_df[no_retweets].shape
# Out:
# (45270, 8)

# %%
tweet_df2['tokens'] = tokens

# %%
tweet_df2.shape
# Out:
# (54442, 17)

# %%
str = ['stock']
matches = [x.lower().split() for x in tweet_df2['text']]
matches
# Out:
# [['republicans',
#   'and',
#   'democrats',
#   'have',
#   'both',
#   'created',
#   'our',
#   'economic',
#   'problems.'],
#  ['i',
#   'was',
#   'thrilled',
#   'to',
#   'be',
#   'back',
#   'in',
#   'the',
#   'great',
#   'city',
#   'of',
#   'charlotte,',
#   'north',
#   'carolina',
#   'with',
#   'thousands',
#   'of',
#   'hardworking',
#   'american',
#   'patriots',
#   'who',
#   'love',
#   'our',
#   'country,',
#   'cherish',
#   'our',
#   'values,',
#   'respect',
#   'our',
#   'laws,',
#   'and',
#   'always',
#   'put',
#   'america',
#   'first!',
#   'thank',
#   'you',
#   'for',
#   'a',
#   'wonderful',
#   'evening!!',
#   '#kag2020',
#   'https://t.co/dnjzfrsl9y'],
#  ['rt',
#   '@cbs_herridge:',
#   'read:',
#   'letter',
#   'to',
#   'surveillance',
#   'court',
#   'obtained',
#   'by',
#   'cbs',
#   'news',
#   'questions',
#   'where',
#   'there',
#   'will',
#   'be',
#   'further',
#   'disciplinary',
#   'action',
#   'and',
#   'cho…'],
#  ['the',
#   'unsolicited',
#   'mail',
#   'in',
#   'ballot',
#   'scam',
#   'is',
#   'a',
#   'major',
#   'threat',
#   'to',
#   'our',
#   'democracy,',
#   '&amp;',
#   'the',
#   'democrats',
#   'know',
#   'it.',
#   'almost',
#   'all',
#   'recent',
#   'elections',
#   'using',
#   'this',
#   'system,',
#   'even',
#   'though',
#   'much',
#   'smaller',
#   '&amp;',
#   'with',
#   'far',
#   'fewer',
#   'ballots',
#   'to',
#   'count,',
#   'have',
#   'ended',
#   'up',
#   'being',
#   'a',
#   'disaster.',
#   'large',
#   'numbers',
#   'of',
#   'missing',
#   'ballots',
#   '&amp;',
#   'fraud!'],
#  ['rt',
#   '@mzhemingway:',
#   'very',
#   'friendly',
#   'telling',
#   'of',
#   'events',
#   'here',
#   'about',
#   "comey's",
#   'apparent',
#   'leaking',
#   'to',
#   'compliant',
#   'media.',
#   'if',
#   'you',
#   'read',
#   'those',
#   'articles',
#   'and',
#   'tho…'],
#  ['thank',
#   'you',
#   'to',
#   'all',
#   'of',
#   'the',
#   'great',
#   'american',
#   'patriots',
#   'in',
#   'the',
#   'villages,',
#   'florida!',
#   '#maga',
#   'https://t.co/cnevwnrove'],
#  ['rt',
#   '@whitehouse:',
#   'president',
#   '@realdonaldtrump',
#   'announced',
#   'historic',
#   'steps',
#   'to',
#   'protect',
#   'the',
#   'constitutional',
#   'right',
#   'to',
#   'pray',
#   'in',
#   'public',
#   'schools!',
#   'https://…'],
#  ['“i’m',
#   'running',
#   'as',
#   'a',
#   'proud',
#   'democrat,',
#   'for',
#   'the',
#   'senate”.',
#   'sleepy',
#   'joe',
#   'biden',
#   'today.',
#   'it’s',
#   'only',
#   'going',
#   'to',
#   'get',
#   'worse.',
#   'it',
#   'is',
#   'not',
#   'sustainable',
#   'for',
#   'our',
#   'county',
#   '-',
#   'china',
#   'will',
#   'own',
#   'us!!!!'],
#  ['getting',
#   'a',
#   'little',
#   'exercise',
#   'this',
#   'morning!',
#   'https://t.co/fyaacbhbgk'],
#  ['https://t.co/lcqcdlrkhz'],
#  ['https://t.co/4v7nu5hh8v'],
#  ['huge',
#   'win',
#   'today',
#   'for',
#   'the',
#   'united',
#   'states',
#   'and',
#   'for',
#   'peace',
#   'in',
#   'the',
#   'world.',
#   'sudan',
#   'has',
#   'agreed',
#   'to',
#   'a',
#   'peace',
#   'and',
#   'normalization',
#   'agreement',
#   'with',
#   'israel!',
#   'with',
#   'the',
#   'united',
#   'arab',
#   'emirates',
#   'and',
#   'bahrain,',
#   'that’s',
#   'three',
#   'arab',
#   'countries',
#   'to',
#   'have',
#   'done',
#   'so',
#   'in',
#   'only',
#   'a',
#   'matter',
#   'of',
#   'weeks.',
#   'more',
#   'will',
#   'follow!',
#   'https://t.co/uhb8h6oazc'],
#  ['rt',
#   '@therightmelissa:',
#   'i',
#   'guarantee',
#   'it',
#   'was',
#   'the',
#   '1st',
#   'time',
#   'millions',
#   'of',
#   'americans',
#   'learned',
#   'the',
#   '“kids',
#   'in',
#   'cages”',
#   'was',
#   'obama',
#   'not',
#   'trump',
#   'because',
#   'the',
#   'medi…'],
#  ['thank', 'you', 'megyn!', 'https://t.co/sc71eewiod'],
#  ['11', 'days!', '#maga', 'https://t.co/puqef1ctds'],
#  ['https://t.co/4qwckqoiow'],
#  ['https://t.co/vleu8yyovv'],
#  ['rt',
#   '@gopchairwoman:',
#   'the',
#   'economic',
#   'boom',
#   'continues!',
#   '273k',
#   'jobs',
#   'added',
#   'in',
#   'february',
#   '7m+',
#   'jobs',
#   'added',
#   'since',
#   '@realdonaldtrump',
#   'was',
#   'elected',
#   'unemploym…'],
#  ['rt',
#   '@tomfitton:',
#   "vindman's",
#   'behavior',
#   'is',
#   'a',
#   'scandal.',
#   'he',
#   'should',
#   'be',
#   'removed',
#   'from',
#   'the',
#   '@realdonaldtrump',
#   'white',
#   'house',
#   'asap',
#   'to',
#   'protect',
#   'our',
#   'foreign',
#   'poli…'],
#  ['https://t.co/z5crqho8vg'],
#  ['https://t.co/tqcqidrvob'],
#  ['rt', '@erictrump:', 'https://t.co/ncrndosfiv'],
#  ['thank', 'you', 'elise!', 'https://t.co/y4hb0zf5jk'],
#  ['as',
#   'per',
#   'your',
#   'request,',
#   'joe...',
#   'https://t.co/78mzcflesf',
#   'https://t.co/aalvksfhfi'],
#  ['rt',
#   '@marklevinshow:',
#   'president',
#   'trump',
#   'was',
#   'outstanding.',
#   'i',
#   "couldn't",
#   'be',
#   'prouder.',
#   'biden',
#   'was',
#   'making',
#   'faces',
#   'and',
#   'was',
#   'very',
#   'dishonest',
#   'about',
#   'some',
#   'of',
#   'hi…'],
#  ['rt',
#   '@realrlimbaugh:',
#   'winning,',
#   'winning,',
#   'winning!',
#   '@realdonaldtrump'],
#  ['rt',
#   '@megynkelly:',
#   'trump',
#   'won',
#   'this',
#   'debate,',
#   'handily.',
#   'biden',
#   'wasn’t',
#   'a',
#   'force',
#   'at',
#   'all.',
#   'trump',
#   'was',
#   'substantive,',
#   'on-point,',
#   'well-tempered.',
#   'definitely',
#   'hel…'],
#  ['nobody',
#   'is',
#   'showing',
#   'up',
#   'for',
#   'obama’s',
#   'hate',
#   'laced',
#   'speeches.',
#   '47',
#   'people!',
#   'no',
#   'energy,',
#   'but',
#   'still',
#   'better',
#   'than',
#   'joe!'],
#  ['just',
#   'landed',
#   'in',
#   'ohio.',
#   'see',
#   'you',
#   'in',
#   'a',
#   'little',
#   'while!'],
#  ['https://t.co/nx5zpbib3e'],
#  ['https://t.co/wuli07jxak'],
#  ['https://t.co/0q33fvaos6'],
#  ['https://t.co/bko27n6tmz'],
#  ['https://t.co/wjn4zv0y8o'],
#  ['https://t.co/gjbmfdbups'],
#  ['obamagate!'],
#  ['$13.9m',
#   'is',
#   'heading',
#   'to',
#   'new',
#   'orleans',
#   'in',
#   '@usdot',
#   'funding',
#   'for',
#   '@neworleansrta!',
#   'happy',
#   'to',
#   'support',
#   'bus',
#   'service',
#   'and',
#   'major',
#   'fleet',
#   'improvements',
#   'for',
#   'the',
#   'great',
#   'people',
#   'of',
#   'louisiana',
#   'and',
#   'help',
#   'them',
#   'keep',
#   'moving',
#   'safely.'],
#  ['tonight', 'at', '9:00', 'p.m.', 'enjoy!', 'https://t.co/wm3hgxnzqm'],
#  ['rt',
#   '@realdonaldtrump:',
#   'wow',
#   'crazy',
#   'nancy,',
#   'what’s',
#   'going',
#   'on?',
#   'this',
#   'is',
#   'big',
#   'stuff!',
#   'https://t.co/hohserkgh9'],
#  ['https://t.co/121kaqlsjq'],
#  ['https://t.co/6bv45ircye'],
#  ['rt', '@erictrump:', 'more', 'voter', 'fraud...', 'https://t.co/g5wahomniz'],
#  ['https://t.co/nyajxa52fs'],
#  ['...based',
#   'on',
#   'decisions',
#   'being',
#   'rendered',
#   'now,',
#   'this',
#   'list',
#   'is',
#   'more',
#   'important',
#   'than',
#   'ever',
#   'before',
#   '(second',
#   'amendment,',
#   'right',
#   'to',
#   'life,',
#   'religous',
#   'liberty,',
#   'etc.)',
#   '–',
#   'vote',
#   '2020!'],
#  ['https://t.co/atxqnfbdms'],
#  ['https://t.co/urqcisejge'],
#  ['no',
#   'matter',
#   'what',
#   'you',
#   'give',
#   'to',
#   'the',
#   'radical',
#   'left,',
#   'do',
#   'nothing',
#   'democrats,',
#   'it',
#   'will',
#   'never',
#   'be',
#   'enough!'],
#  ['https://t.co/kr5e8r90ey'],
#  ['https://t.co/dubjypmqj2'],
#  ['https://t.co/2qqn6whjyf'],
#  ['rt',
#   '@repmarkmeadows:',
#   'the',
#   'fbi',
#   'lied',
#   'to',
#   'the',
#   'fisa',
#   'court',
#   '17',
#   'times,',
#   'using',
#   'knowingly',
#   'false',
#   'info',
#   'in',
#   'fisa',
#   'applications,',
#   'concealed',
#   'exonerating',
#   'evidenc…'],
#  ['rt', '@scavino45:', 'https://t.co/f7mv1fztjn'],
#  ['coldcasejoe!', 'https://t.co/4ewns6fzcx'],
#  ['big',
#   'victory',
#   'for',
#   'patients',
#   '–',
#   'federal',
#   'court',
#   'upholds',
#   'hospital',
#   'price',
#   'transparency.',
#   'patients',
#   'deserve',
#   'to',
#   'know',
#   'the',
#   'price',
#   'of',
#   'care',
#   'before',
#   'they',
#   'enter',
#   'the',
#   'hospital.',
#   'because',
#   'of',
#   'my',
#   'action,',
#   'they',
#   'will.',
#   'this',
#   'may',
#   'very',
#   'well',
#   'be',
#   'bigger',
#   'than',
#   'healthcare',
#   'itself.',
#   'congratulations',
#   'america!'],
#  ['rt',
#   '@senjohnthune:',
#   'everything',
#   'we’re',
#   'doing',
#   'right',
#   'now',
#   'is',
#   'time-sensitive.',
#   'just',
#   'left',
#   'lunch',
#   'with',
#   '@senategop',
#   '&amp;',
#   '@stevenmnuchin1.',
#   'we’re',
#   'working',
#   'as',
#   'a…'],
#  ['rt', '@realdonaldtrump:', 'law', '&amp;', 'order!!!'],
#  ['thank', 'you', 'harry!', 'https://t.co/vu7aasoyrx'],
#  ['rt',
#   '@paulsperry_:',
#   'fun',
#   'fact',
#   'for',
#   'patriots:',
#   'presidents',
#   'thomas',
#   'jefferson',
#   'and',
#   'john',
#   'adams',
#   'died',
#   'on',
#   'the',
#   'same',
#   'day',
#   '--',
#   'july',
#   '4,',
#   '1826',
#   '--and',
#   'within',
#   'five',
#   'h…'],
#  ['rushing',
#   'him',
#   'out',
#   'of',
#   'basement',
#   'after',
#   'seeing',
#   'some',
#   'very',
#   'disturbing',
#   'numbers.',
#   'don’t',
#   'worry,',
#   'he’ll',
#   'go',
#   'back',
#   'to',
#   'basement',
#   'soon!',
#   'https://t.co/cemq5xowqt'],
#  ['sleepy', 'eyes', 'fails', 'again!', 'https://t.co/mc7ksbo4cd'],
#  ['happy', 'easter!'],
#  ['rt',
#   '@bhuvanbagga:',
#   'the',
#   "world's",
#   'newest',
#   '&amp;',
#   'biggest',
#   '#cricket',
#   'stadium',
#   '--',
#   'also',
#   'the',
#   'venue',
#   'of',
#   'joint',
#   'modi-trump',
#   'visit',
#   'in',
#   'western',
#   "#india's",
#   'gujarat',
#   'stat…'],
#  ['rt',
#   '@greggjarrett:',
#   'comey',
#   '(and',
#   'the',
#   'media’s)',
#   'coverup',
#   'unravels',
#   'https://t.co/ebwljw4e2x'],
#  ['much',
#   'more',
#   '“disinformation”',
#   'coming',
#   'out',
#   'of',
#   'cnn,',
#   'msdnc,',
#   '@nytimes',
#   'and',
#   '@washingtonpost,',
#   'by',
#   'far,',
#   'than',
#   'coming',
#   'out',
#   'of',
#   'any',
#   'foreign',
#   'country,',
#   'even',
#   'combined.',
#   'fake',
#   'news',
#   'is',
#   'the',
#   'enemy',
#   'of',
#   'the',
#   'people!'],
#  ['watch', 'the', 'ballots!!!'],
#  ['https://t.co/4jizofzal4'],
#  ['new', 'record', 'for', 'nasdaq!'],
#  ['rt',
#   '@repmarkmeadows:',
#   'there',
#   'is',
#   'no',
#   'other',
#   'way',
#   'to',
#   'spin',
#   'it:',
#   'the',
#   'response',
#   'today',
#   'from',
#   'the',
#   'president’s',
#   'legal',
#   'team',
#   'has',
#   'been',
#   'absolutely',
#   'devastating',
#   'to…'],
#  ['so', 'great', 'for', 'the', 'world!', 'https://t.co/piyo55tea8'],
#  ['rt',
#   '@trumpwarroom:',
#   'watch:',
#   'after',
#   'joe',
#   "biden's",
#   'brain',
#   'freezes,',
#   'msnbc',
#   'anchor',
#   'has',
#   'to',
#   'feed',
#   'him',
#   'a',
#   'line',
#   'https://t.co/pymkxjlqhf'],
#  ['great',
#   'story.',
#   'thank',
#   'you',
#   'to',
#   'mr.',
#   'young',
#   'of',
#   'jonesboro,',
#   'arkansas!',
#   'https://t.co/i9xh8vxfs2'],
#  ['rt',
#   '@loudobbs:',
#   'president’s',
#   'lawyers',
#   'dissected',
#   'the',
#   'radical',
#   'dems',
#   'efforts',
#   'to',
#   'overthrow',
#   '@realdonaldtrump',
#   'under',
#   'the',
#   'guise',
#   'of',
#   'what',
#   'has',
#   'been',
#   'clearly…'],
#  ['rt',
#   '@gopleader:',
#   'no',
#   'wonder',
#   'chairman',
#   'adam',
#   'schiff',
#   'wouldn’t',
#   'let',
#   'the',
#   'president’s',
#   'lawyers',
#   'participate',
#   'in',
#   'his',
#   'sham',
#   'hearings.',
#   'they',
#   'just',
#   'dismantled',
#   'h…'],
#  ['rt', '@realdonaldtrump:', 'https://t.co/ij18ydpc68'],
#  ['rt',
#   '@whitehouse:',
#   '"my',
#   'administration',
#   'will',
#   'always',
#   'stand',
#   'against',
#   'violence,',
#   'mayhem,',
#   'and',
#   'disorder.',
#   'we',
#   'will',
#   'stand',
#   'with',
#   'the',
#   'family',
#   'of',
#   'george',
#   'floyd…'],
#  ['rt',
#   '@whitehouse:',
#   'live:',
#   'president',
#   '@realdonaldtrump',
#   'holds',
#   'a',
#   'news',
#   'conference',
#   'https://t.co/cnowdtlxgc'],
#  ['rt',
#   '@mike_pence:',
#   'nearly',
#   '4',
#   'years',
#   'ago',
#   'president',
#   '@realdonaldtrump',
#   'told',
#   'america',
#   'and',
#   'the',
#   'world:',
#   '“we',
#   'stand',
#   'at',
#   'the',
#   'birth',
#   'of',
#   'a',
#   'new',
#   'millennium,',
#   'ready…'],
#  ['rt',
#   '@mike_pence:',
#   'today',
#   'is',
#   'the',
#   'culmination',
#   'of',
#   'three',
#   'and',
#   'a',
#   'half',
#   'years',
#   'of',
#   'renewed',
#   'leadership',
#   'in',
#   'space.',
#   'it’s',
#   'a',
#   'tribute',
#   'to',
#   'the',
#   'courage',
#   'of',
#   'our',
#   'ast…'],
#  ['great', 'book!', 'https://t.co/h6j5jlw1mf'],
#  ['https://t.co/hofqef1hum'],
#  ['rt',
#   '@teamtrump:',
#   'president',
#   '@realdonaldtrump:',
#   'the',
#   '20',
#   'most',
#   'dangerous',
#   'american',
#   'cities',
#   'are',
#   'democrat',
#   'run',
#   'https://t.co/gb9rnytfha'],
#  ['a',
#   'giant',
#   'scam,',
#   'and',
#   'the',
#   'dems',
#   'know',
#   'it!',
#   'https://t.co/enqhp7tfxl'],
#  ['rt',
#   '@ronaldjhansen:',
#   'no',
#   'one',
#   'seems',
#   'to',
#   'be',
#   'having',
#   'more',
#   'fun',
#   'or',
#   'getting',
#   'a',
#   'warmer',
#   'reception',
#   'at',
#   '@azgop',
#   'meeting',
#   'than',
#   '@repdlesko,',
#   'who',
#   'is',
#   'part',
#   'of',
#   '@real…'],
#  ['rt',
#   '@scottpresler:',
#   'georgia’s',
#   '6th',
#   'district',
#   'is',
#   'flippable.',
#   'this',
#   'one’s',
#   'for',
#   'you,',
#   'cobb,',
#   'fulton,',
#   '&amp;',
#   'dekalb',
#   'counties.',
#   'https://t.co/08rpm4e2kv',
#   '#ga…'],
#  ['crazy',
#   'bernie',
#   'sanders',
#   'is',
#   'not',
#   'a',
#   'fighter.',
#   'he',
#   'gives',
#   'up',
#   'too',
#   'easy!',
#   'the',
#   'dem',
#   'establishment',
#   'gets',
#   'alfred',
#   'e.',
#   'newman',
#   '(mayor',
#   'pete)',
#   '&amp;',
#   '@amyklobuchar',
#   'to',
#   'quit',
#   '&amp;',
#   'endorse',
#   'sleepy',
#   'joe',
#   'before',
#   'super',
#   'tuesday,',
#   '&amp;',
#   'gets',
#   'pocahontas',
#   'to',
#   'stay',
#   'in',
#   'the',
#   'race,',
#   'taking',
#   'thousands',
#   'of',
#   'votes',
#   'from',
#   'bernie.',
#   'he',
#   'would',
#   'have....'],
#  ['when',
#   'are',
#   'the',
#   'thugs,',
#   'looters,',
#   'and',
#   'anarchists',
#   'moving',
#   'out',
#   'of',
#   'the',
#   'so-called',
#   '“autonomous',
#   'zone”',
#   'in',
#   'seattle?',
#   'get',
#   'going!'],
#  ['vote!', 'https://t.co/plvmieegan'],
#  ['rt',
#   '@kimfreethinker:',
#   'our',
#   'president',
#   'is',
#   'working',
#   'valiantly',
#   'to',
#   'face',
#   'some',
#   'thing',
#   'unprecedented',
#   'and',
#   'he’s',
#   'met',
#   'with',
#   'the',
#   'ignorance',
#   'seen',
#   'in',
#   'this',
#   'video.…'],
#  ['rt',
#   '@replouiegohmert:',
#   'keep',
#   'it',
#   'up',
#   '@thejusticedept.',
#   "we've",
#   'got',
#   'a',
#   'long',
#   'way',
#   'to',
#   'go',
#   'with',
#   'these',
#   'so-called',
#   '"peaceful',
#   'protesters"'],
#  ['rt',
#   '@andrewhclark:',
#   'cuomo',
#   'mismanaged',
#   'new',
#   "york's",
#   'coronavirus',
#   'response.',
#   'tens',
#   'of',
#   'thousands',
#   'in',
#   'nursing',
#   'homes',
#   'unnecessarily',
#   'died,',
#   'and',
#   'his',
#   'arroga…'],
#  ['rt',
#   '@whitehouse:',
#   'live:',
#   'president',
#   '@realdonaldtrump',
#   'gives',
#   'an',
#   'update',
#   'on',
#   'coronavirus',
#   'testing',
#   'strategy',
#   'https://t.co/dp6faknavo'],
#  ['vote!', 'https://t.co/nacpezqrmt'],
#  ['https://t.co/expcuqdwu5'],
#  ['rt',
#   '@tomfitton:',
#   'antifa',
#   'has',
#   'been',
#   'engaging',
#   'in',
#   'terrorism',
#   'and',
#   'seditious',
#   'conspiracy',
#   'for',
#   'years.',
#   'but',
#   'fbi',
#   'and',
#   'doj',
#   'were',
#   'too',
#   'busy',
#   'to',
#   'care',
#   'much,',
#   'their…'],
#  ['rt',
#   '@bucksexton:',
#   'this',
#   'isn’t',
#   'going',
#   'to',
#   'stop',
#   'until',
#   'the',
#   'good',
#   'guys',
#   'are',
#   'willing',
#   'to',
#   'use',
#   'overwhelming',
#   'force',
#   'against',
#   'the',
#   'bad',
#   'guys'],
#  ['corrupt',
#   'joe',
#   'biden',
#   'and',
#   'the',
#   'democrats',
#   'don’t',
#   'want',
#   'to',
#   'open',
#   'schools',
#   'in',
#   'the',
#   'fall',
#   'for',
#   'political',
#   'reasons,',
#   'not',
#   'for',
#   'health',
#   'reasons!',
#   'they',
#   'think',
#   'it',
#   'will',
#   'help',
#   'them',
#   'in',
#   'november.',
#   'wrong,',
#   'the',
#   'people',
#   'get',
#   'it!'],
#  ['https://t.co/dc5qlivhwh'],
#  ['rt',
#   '@presssec:',
#   'arizona',
#   'is',
#   'booming',
#   'thanks',
#   'to',
#   'president',
#   '@realdonaldtrump.',
#   'unemployment',
#   'is',
#   'falling',
#   '&amp;',
#   'labor',
#   'force',
#   'participation',
#   'is',
#   'rising!',
#   '✅239…'],
#  ['rt',
#   '@david_bossie:',
#   'new',
#   'digital',
#   'ad',
#   'up',
#   'in',
#   'battleground',
#   'states',
#   'today',
#   'highlighting',
#   '@realdonaldtrump',
#   'strong',
#   'leadership',
#   'combating',
#   'the',
#   'coronavirus…'],
#  ['law', '&amp;', 'order!'],
#  ['https://t.co/runkw7pxyv'],
#  ['https://t.co/xyygel5mng'],
#  ['rt',
#   '@teamtrump:',
#   'president',
#   '@realdonaldtrump',
#   'is',
#   'in',
#   'yuma,',
#   'arizona',
#   'to',
#   'proudly',
#   'accept',
#   'the',
#   'endorsement',
#   'of',
#   'the',
#   'national',
#   'border',
#   'patrol',
#   'council!',
#   'http…'],
#  ['rt',
#   '@sentedcruz:',
#   '.@foxnews:',
#   'sen.',
#   'cruz:',
#   'rioting',
#   'cannot',
#   'be',
#   'tolerated,',
#   'this',
#   'is',
#   "'terrorist",
#   "assault'",
#   'on',
#   'america',
#   'https://t.co/l8shts1zvj'],
#  ['thank',
#   'you',
#   'ted.',
#   'they',
#   'got',
#   'caught',
#   'cold,',
#   'but',
#   'this',
#   'should',
#   'never',
#   'be',
#   'allowed',
#   'to',
#   'happen',
#   'to',
#   'an',
#   'incoming',
#   'administration',
#   'again',
#   '-',
#   'spied',
#   'on.',
#   'makes',
#   'watergate',
#   'look',
#   'like',
#   'small',
#   'potatoes!',
#   'obamagate!',
#   'https://t.co/it9trys8sk'],
#  ['https://t.co/cvx8hpptvd'],
#  ['https://t.co/ozyzlq2fqp'],
#  ['sleepy',
#   'joe',
#   'thought',
#   'this',
#   'was',
#   'ok.',
#   'not',
#   'me!',
#   'https://t.co/vgila4fjkf'],
#  ['rt',
#   '@nolaready:',
#   'primary',
#   'threat',
#   'from',
#   '#laura',
#   'in',
#   '#nola',
#   'is',
#   'storm',
#   'surge',
#   'outside',
#   'the',
#   'levee',
#   'system.',
#   'could',
#   'also',
#   'see',
#   'heavy',
#   'rain,',
#   'wind',
#   '&amp;',
#   'tornadoes',
#   'if…'],
#  ['rt',
#   '@gopchairwoman:',
#   '“we',
#   'are',
#   'determined',
#   'to',
#   'protect',
#   'our',
#   'african',
#   'american,',
#   'hispanic',
#   'american,',
#   'and',
#   'minority',
#   'workers',
#   'who',
#   'have',
#   'been',
#   'hit',
#   'so',
#   'hard',
#   'by…'],
#  ['rt', '@jennpellegrino:', 'can’t', 'wait', 'to', 'watch!'],
#  ['rt',
#   '@whitehouse:',
#   '"as',
#   'president,',
#   'i',
#   'am',
#   'absolutely',
#   'determined',
#   'to',
#   'deliver',
#   'a',
#   'great',
#   'future',
#   'for',
#   'americans',
#   'of',
#   'every',
#   'race,',
#   'religion,',
#   'color,',
#   'and',
#   'creed…'],
#  ['https://t.co/uwydwodqgp'],
#  ['i',
#   'am',
#   'proud',
#   'to',
#   'announce',
#   '$2',
#   'million',
#   'for',
#   'the',
#   '@sept11memorial',
#   'in',
#   'nyc!',
#   'this',
#   'special',
#   'site',
#   'ensures',
#   'that',
#   'the',
#   'memory',
#   'of',
#   'the',
#   'nearly',
#   '3,000',
#   'people',
#   'killed',
#   'in',
#   'the',
#   'terror',
#   'attacks',
#   'of',
#   'september',
#   '11,',
#   '2001,',
#   'as',
#   'well',
#   'as',
#   'those',
#   'lost',
#   'in',
#   'the',
#   'world',
#   'trade',
#   'center',
#   'bombing',
#   'in',
#   '1993,',
#   'will',
#   'never',
#   'be',
#   'forgotten!'],
#  ['great',
#   'to',
#   'be',
#   'with',
#   'our',
#   'wonderful',
#   'men',
#   'and',
#   'women',
#   'of',
#   'the',
#   '@secretservice.',
#   'what',
#   'a',
#   'job',
#   'they',
#   'are',
#   'doing!',
#   'https://t.co/qebvy1jdup'],
#  ['nobody',
#   'fights',
#   'harder',
#   'for',
#   'montana',
#   'than',
#   '@stevedaines.',
#   'steve',
#   'is',
#   'a',
#   'close',
#   'friend',
#   'of',
#   'mine,',
#   'a',
#   'strong',
#   'conservative,',
#   'and',
#   'a',
#   'tremendous',
#   'supporter',
#   'of',
#   'our',
#   '#maga',
#   'agenda.',
#   'he',
#   'is',
#   'strong',
#   'on',
#   'crime',
#   '&amp;',
#   'borders,',
#   'great',
#   'for',
#   'our',
#   'military',
#   '&amp;',
#   'vets,',
#   '&amp;',
#   'will',
#   'protect',
#   'your',
#   '#2a.',
#   'steve',
#   'has',
#   'my',
#   'complete',
#   'endorsement!'],
#  ['on',
#   'my',
#   'way',
#   'to',
#   'the',
#   'great',
#   'state',
#   'of',
#   'south',
#   'carolina.',
#   'see',
#   'everyone',
#   'soon!',
#   '#maga',
#   '#kag',
#   'https://t.co/cjzelgnydn'],
#  ['https://t.co/l00a2im766'],
#  ['the',
#   'democrats,',
#   'together',
#   'with',
#   'the',
#   'corrupt',
#   'fake',
#   'news',
#   'media,',
#   'have',
#   'launched',
#   'a',
#   'massive',
#   'disinformation',
#   'campaign',
#   'the',
#   'likes',
#   'of',
#   'which',
#   'has',
#   'never',
#   'been',
#   'seen',
#   'before.',
#   'they',
#   'will',
#   'say',
#   'anything,',
#   'like',
#   'their',
#   'recent',
#   'lies',
#   'about',
#   'me',
#   'and',
#   'the',
#   'military,',
#   'and',
#   'hope',
#   'that',
#   'it',
#   'sticks...',
#   'but',
#   '#maga',
#   'gets',
#   'it!'],
#  ['rt',
#   '@senbillcassidy:',
#   'did',
#   'anyone',
#   'else',
#   'just',
#   'get',
#   'chills?',
#   'we.',
#   'are.',
#   'back.',
#   '🚀🇺🇸'],
#  ['rt',
#   '@nationalmallnps:',
#   'in',
#   'the',
#   'wake',
#   'of',
#   'last',
#   "night's",
#   'demonstrations,',
#   'there',
#   'are',
#   'numerous',
#   'instances',
#   'of',
#   'vandalism',
#   'to',
#   'sites',
#   'around',
#   'the',
#   'national',
#   'mal…'],
#  ['https://t.co/rehbrvecc0'],
#  ['rt',
#   '@senategop:',
#   '"darkness',
#   'cannot',
#   'drive',
#   'out',
#   'darkness;',
#   'only',
#   'light',
#   'can',
#   'do',
#   'that.',
#   'hate',
#   'cannot',
#   'drive',
#   'out',
#   'hate;',
#   'only',
#   'love',
#   'can',
#   'do',
#   'that."',
#   '-',
#   'martin',
#   'l…'],
#  ['rt',
#   '@grassleypress:',
#   'yesterday,',
#   'the',
#   'senate',
#   'passed',
#   'the',
#   '#ppp',
#   'flexibility',
#   'act',
#   'of',
#   '2020.',
#   'here’s',
#   'what',
#   'you',
#   'need',
#   'to',
#   'know:',
#   '-',
#   'the',
#   'loan',
#   'forgiveness',
#   'per…'],
#  ['rt',
#   '@ingrahamangle:',
#   'or',
#   'course!',
#   'they',
#   'don’t',
#   'want',
#   'biden',
#   'to',
#   'have',
#   'to',
#   'speak',
#   'or',
#   'debate',
#   'or',
#   'campaign.'],
#  ['rt',
#   '@senjoniernst:',
#   'right',
#   'now,',
#   'we',
#   'can’t',
#   'hear',
#   'the',
#   'peaceful',
#   'protesters’',
#   'voices',
#   'over',
#   'the',
#   'sounds',
#   'of',
#   'shattering',
#   'glass',
#   'and',
#   'splintering',
#   'woods.',
#   'vio…'],
#  ['https://t.co/jp8kzem9bk'],
#  ['usa!', 'https://t.co/p6lrdnksb9'],
#  ['rt',
#   '@senronjohnson:',
#   'one',
#   'thing',
#   'we',
#   'have',
#   'found',
#   'out',
#   'from',
#   'declassified',
#   'information',
#   'is',
#   'that',
#   'the',
#   'fbi',
#   'was',
#   'ready',
#   'to',
#   'close',
#   'the',
#   'file',
#   'on',
#   'general',
#   'flynn',
#   'o…'],
#  ['congratulations', 'to', 'sleepy', 'joe', 'biden!'],
#  ['rt',
#   '@realdailywire:',
#   'biden',
#   'is',
#   '‘a',
#   'trojan',
#   'horse',
#   'for',
#   'a',
#   'radical',
#   'agenda,’',
#   'mike',
#   'pence',
#   'warns',
#   'https://t.co/bb8crpql4w',
#   'https://t.co/sy8x983b8i'],
#  ['rt',
#   '@erictrump:',
#   'thank',
#   'you',
#   'to',
#   'all',
#   'of',
#   'our',
#   'incredible',
#   'friends',
#   'at',
#   'the',
#   '@nhra',
#   'u.s.',
#   'nationals',
#   'in',
#   'indianapolis!',
#   'we',
#   'love',
#   'and',
#   'appreciate',
#   'you',
#   '—',
#   '@realdo…'],
#  ['rt',
#   '@parisdennard:',
#   'in',
#   '@joebiden’s',
#   'america',
#   '-police',
#   'are',
#   'defunded',
#   '-communities',
#   'are',
#   'less',
#   'safe',
#   '-taxes',
#   'go',
#   'up',
#   '-',
#   'opportunity',
#   'zones',
#   'will',
#   'stop',
#   '-…'],
#  ['congressman',
#   '@davejoyceoh14',
#   'is',
#   'a',
#   'tremendous',
#   'fighter',
#   'for',
#   'the',
#   'great',
#   'state',
#   'of',
#   'ohio!',
#   'he',
#   'is',
#   'tough',
#   'on',
#   'crime,',
#   'our',
#   'border,',
#   'second',
#   'amendment,',
#   'and',
#   'helps',
#   'us',
#   'combat',
#   'illegal',
#   'drugs!',
#   'david',
#   'has',
#   'my',
#   'complete',
#   'and',
#   'total',
#   'endorsement!',
#   'https://t.co/odaeppur3w'],
#  ['rt', '@senronjohnson:', 'thanks,', '@realdonaldtrump'],
#  ['rt',
#   '@senronjohnson:',
#   'talking',
#   'with',
#   '@jaketapper',
#   'on',
#   '@cnnsotu',
#   'about',
#   'the',
#   'recently',
#   'declassified',
#   'list',
#   'of',
#   'obama-era',
#   'officials',
#   'who',
#   'were',
#   'behind',
#   'the',
#   'unm…'],
#  ['rt', '@_sbenitez:', 'gracias', '@fabioasays', '🇺🇸!'],
#  ['rt',
#   '@greggjarrett:',
#   'extortion,',
#   'bribery',
#   'and',
#   'sex',
#   'trafficking:',
#   'the',
#   'truth',
#   'about',
#   'hunter',
#   'biden',
#   'https://t.co/vicl57xkyb'],
#  ['rt',
#   '@senshelby:',
#   'more',
#   'help',
#   'is',
#   'on',
#   'the',
#   'way',
#   'for',
#   'small',
#   'businesses',
#   'in',
#   '#alabama',
#   '&amp;',
#   'across',
#   'the',
#   'nation:',
#   'the',
#   'senate',
#   'passed',
#   'changes',
#   'to',
#   'improve',
#   'the',
#   'histo…'],
#  ['rt',
#   '@senatorfischer:',
#   'you',
#   'can',
#   'still',
#   'apply',
#   'until',
#   'august',
#   '28,',
#   '2020.',
#   'contact',
#   'your',
#   'local',
#   'farm',
#   'service',
#   'agency',
#   'to',
#   'see',
#   'if',
#   'you',
#   'qualify.'],
#  ['coronavirus:',
#   'in',
#   'addition',
#   'to',
#   'screening',
#   'travelers',
#   '“prior',
#   'to',
#   'boarding”',
#   'from',
#   'certain',
#   'designated',
#   'high',
#   'risk',
#   'countries,',
#   'or',
#   'areas',
#   'within',
#   'those',
#   'countries,',
#   'they',
#   'will',
#   'also',
#   'be',
#   'screened',
#   'when',
#   'they',
#   'arrive',
#   'in',
#   'america.',
#   'thank',
#   'you!',
#   '@vp',
#   '@secazar',
#   '@cdcgov',
#   '@cdcdirector'],
#  ['https://t.co/x6ra8feso7'],
#  ['mini',
#   'mike',
#   'bloomberg',
#   'didn’t',
#   'bring',
#   'nyc',
#   'back,',
#   'as',
#   'he',
#   'said',
#   'in',
#   'his',
#   'fake',
#   'ad.',
#   'it',
#   'was',
#   '@rudygiuliani',
#   'who',
#   'brought',
#   'nyc',
#   'back',
#   'and',
#   'who',
#   'also,',
#   'with',
#   'his',
#   'endorsement,',
#   'got',
#   'mini',
#   'mike',
#   'elected',
#   '(with',
#   'barely',
#   'a',
#   'thank',
#   'you).',
#   'a',
#   'boring',
#   'mayor',
#   'who',
#   'the',
#   'people',
#   'couldn’t',
#   'stand!'],
#  ['https://t.co/enqz4enzd6'],
#  ['rt',
#   '@realdonaldtrump:',
#   'corrupt',
#   'joe',
#   'biden',
#   'wants',
#   'to',
#   'defund',
#   'our',
#   'police.',
#   'he',
#   'may',
#   'use',
#   'different',
#   'words,',
#   'but',
#   'when',
#   'you',
#   'look',
#   'at',
#   'his',
#   'pact',
#   'with',
#   'crazy',
#   'ber…'],
#  ['rt',
#   '@timmurtaugh:',
#   '...',
#   'across',
#   'the',
#   'united',
#   'states,',
#   'effectively',
#   'bankrupting',
#   'and',
#   'destroying',
#   'them.',
#   'joe',
#   'biden',
#   'is',
#   'an',
#   'empty',
#   'vessel,',
#   'which',
#   'the',
#   'extreme…'],
#  ['rt',
#   '@sentoomey:',
#   'as',
#   '@zoom_us',
#   'user,',
#   'it’s',
#   'exciting',
#   'see',
#   'them',
#   'opening',
#   'a',
#   'new',
#   'r+d',
#   'office',
#   'in',
#   'pittsburgh,',
#   'adding',
#   'several',
#   'hundred',
#   'jobs.',
#   'i',
#   'have',
#   'no',
#   'doub…'],
#  ['rt',
#   '@gop:',
#   'joe',
#   'biden',
#   'is',
#   'on',
#   'a',
#   'mission',
#   'to',
#   'eliminate',
#   'as',
#   'many',
#   'american',
#   'jobs',
#   'as',
#   'possible.',
#   'no',
#   'wonder',
#   'union',
#   'workers',
#   'in',
#   'pennsylvania',
#   'tell',
#   'the',
#   'washi…'],
#  ['rt',
#   '@johnboozman:',
#   "i'm",
#   'pleased',
#   'ar',
#   'farmers',
#   'and',
#   'ranchers',
#   'are',
#   'getting',
#   'assistance',
#   'as',
#   'a',
#   'result',
#   'of',
#   'the',
#   'coronavirus',
#   'food',
#   'assistance',
#   'program:',
#   '8,223…'],
#  ['just',
#   'spoke',
#   'to',
#   'my',
#   'friend,',
#   'president',
#   'joko',
#   'widodo',
#   'of',
#   'the',
#   'republic',
#   'of',
#   'indonesia.',
#   'asking',
#   'for',
#   'ventilators,',
#   'which',
#   'we',
#   'will',
#   'provide.',
#   'great',
#   'cooperation',
#   'between',
#   'us!'],
#  ['rt',
#   '@nedryun:',
#   '"the',
#   'riots',
#   'were',
#   'never',
#   'a',
#   'popular',
#   'uprising;',
#   'rather,',
#   'they',
#   'were',
#   'always',
#   'the',
#   'work',
#   'of',
#   'elite',
#   'democrats:',
#   'that',
#   'is,',
#   'state',
#   'and',
#   'local',
#   'democ…'],
#  ['rt',
#   '@danscavino:',
#   'beckley,',
#   'west',
#   'virginia',
#   '#trumppence2020',
#   '#kag2020',
#   'https://t.co/gegmunszoj'],
#  ['hurricane',
#   'laura',
#   'is',
#   'a',
#   'very',
#   'dangerous',
#   'and',
#   'rapidly',
#   'intensifying',
#   'hurricane.',
#   'my',
#   'administration',
#   'remains',
#   'fully',
#   'engaged',
#   'with',
#   'state',
#   '&amp;',
#   'local',
#   'emergency',
#   'managers',
#   'to',
#   'continue',
#   'preparing',
#   'and',
#   'assisting',
#   'the',
#   'great',
#   'people',
#   'texas,',
#   'louisiana,',
#   'and',
#   'arkansas.',
#   'listen',
#   'to',
#   'local',
#   'officials.',
#   'we',
#   'are',
#   'with',
#   'you!',
#   'https://t.co/x0joijlupb'],
#  ['rt',
#   '@sentoomey:',
#   'caring',
#   'for',
#   'a',
#   'loved',
#   'one',
#   'with',
#   "alzheimer's",
#   'is',
#   'difficult',
#   'even',
#   'in',
#   'the',
#   'best',
#   'of',
#   'times.',
#   'if',
#   'you',
#   'or',
#   'someone',
#   'you',
#   'know',
#   'is',
#   'suffering',
#   'from…'],
#  ['make', 'america', 'great', 'again!'],
#  ['https://t.co/g0jj6gfifs'],
#  ['thank',
#   'you',
#   'for',
#   'the',
#   'good',
#   'reviews',
#   'and',
#   'comments',
#   'on',
#   'my',
#   'interview',
#   'with',
#   'chris',
#   'wallace',
#   'of',
#   '@foxnews.',
#   'we',
#   'may',
#   'have',
#   'set',
#   'a',
#   'record',
#   'for',
#   'doing',
#   'such',
#   'an',
#   'interview',
#   'in',
#   'the',
#   'heat.',
#   'it',
#   'was',
#   '100',
#   'degrees,',
#   'making',
#   'things',
#   'very',
#   'interesting!'],
#  ['rt',
#   '@sencorygardner:',
#   'the',
#   'ppp',
#   'has',
#   'already',
#   'provided',
#   'more',
#   'than',
#   '98,000',
#   'loans',
#   'in',
#   'colorado',
#   'and',
#   'these',
#   'modifications',
#   'will',
#   'increase',
#   'flexibility',
#   'to',
#   'he…'],
#  ['https://t.co/cosg12shw0'],
#  ['https://t.co/vhnde0olav'],
#  ['rt',
#   '@senthomtillis:',
#   'today',
#   'at',
#   '9:40',
#   'am',
#   '46th',
#   'telephone',
#   'town',
#   'hall',
#   'topic:',
#   '#covid19nc',
#   'listen',
#   'live:',
#   'https://t.co/ejmmqn1q7u',
#   'https://t.co/p5mkqru05g'],
#  ['rt',
#   '@sencorygardner:',
#   'yesterday',
#   'the',
#   'senate',
#   'passed',
#   'a',
#   'version',
#   'of',
#   'my',
#   'ppp',
#   'flexibility',
#   'act',
#   'to',
#   'extend',
#   'the',
#   '#paycheckprotectionprogram',
#   'loan',
#   'period',
#   '&amp;…'],
#  ['rt',
#   '@realdonaldtrump:',
#   'a',
#   'poll',
#   'in',
#   'today’s',
#   'new',
#   'york',
#   'post',
#   'says',
#   'that',
#   '77%',
#   'of',
#   '“u.s.',
#   'adults',
#   'have',
#   'confidence',
#   'in',
#   'their',
#   'government’s',
#   'ability',
#   'to',
#   'handle…'],
#  ['https://t.co/ranjvhacoe'],
#  ['rt', '@senjoniernst:', '🇺🇸', 'https://t.co/p0pe0uoqum'],
#  ['exclusive:',
#   'zach',
#   'fuentes,',
#   'top',
#   'aide',
#   'to',
#   'john',
#   'kelly,',
#   'denies',
#   'atlantic',
#   'story',
#   'about',
#   'trump',
#   'https://t.co/rxrpkhdpb1',
#   'via',
#   '@breitbartnews',
#   'thanks',
#   'zach.',
#   'just',
#   'more',
#   'corrupt',
#   'fake',
#   'news',
#   'trying',
#   'to',
#   'change',
#   'the',
#   'course',
#   'of',
#   'our',
#   'most',
#   'important,',
#   'ever,',
#   'election!'],
#  ['https://t.co/2xbefs5lbz'],
#  ['hope',
#   'hicks,',
#   'who',
#   'has',
#   'been',
#   'working',
#   'so',
#   'hard',
#   'without',
#   'even',
#   'taking',
#   'a',
#   'small',
#   'break,',
#   'has',
#   'just',
#   'tested',
#   'positive',
#   'for',
#   'covid',
#   '19.',
#   'terrible!',
#   'the',
#   'first',
#   'lady',
#   'and',
#   'i',
#   'are',
#   'waiting',
#   'for',
#   'our',
#   'test',
#   'results.',
#   'in',
#   'the',
#   'meantime,',
#   'we',
#   'will',
#   'begin',
#   'our',
#   'quarantine',
#   'process!'],
#  ['rt',
#   '@sentomcotton:',
#   'the',
#   'president',
#   'should',
#   'use',
#   'the',
#   'insurrection',
#   'act',
#   'to',
#   'deploy',
#   'active-duty',
#   'military',
#   'forces',
#   'to',
#   'these',
#   'cities',
#   'to',
#   'support',
#   'local',
#   'law…'],
#  ['these', 'numbers', 'are', 'incredible!', '@mariabartiromo'],
#  ['https://t.co/fzof42hqip'],
#  ['.@cnn',
#   'is',
#   'fake',
#   'news,',
#   'and',
#   'all',
#   'smart',
#   'people',
#   'know',
#   'that!',
#   'https://t.co/fqykkhxmx5'],
#  ['rt',
#   '@teamtrump:',
#   'president',
#   '@realdonaldtrump:',
#   'my',
#   'administration',
#   'has',
#   'zero',
#   'outstanding',
#   'requests',
#   'for',
#   'equipment',
#   'from',
#   'the',
#   'states',
#   'https://t.co/yoah5…'],
#  ['rt',
#   '@realdonaldtrump:',
#   'senator',
#   'john',
#   'cornyn',
#   'has',
#   'done',
#   'an',
#   'outstanding',
#   'job',
#   'for',
#   'the',
#   'people',
#   'of',
#   'texas.',
#   'he',
#   'is',
#   'strong',
#   'on',
#   'crime,',
#   'the',
#   'border,',
#   'the',
#   'second…'],
#  ['rt',
#   '@tvnewshq:',
#   'watch:',
#   'youtube',
#   'has',
#   'become',
#   '“a',
#   'key',
#   'battleground',
#   'for',
#   'the',
#   'trump',
#   'campaign”',
#   '—',
#   'the',
#   'hill’s',
#   'media',
#   'reporter',
#   '@joeconchatv',
#   'tells',
#   'fox',
#   'http…'],
#  ['https://t.co/lrg4czwogs'],
#  ['this',
#   'is',
#   'an',
#   'amazing',
#   'jobs',
#   'report!',
#   'edward',
#   'lawrence',
#   '@foxnews'],
#  ['rt',
#   '@whitehouse:',
#   '"as',
#   'one',
#   'family,',
#   'we',
#   'mourn',
#   'every',
#   'precious',
#   'life',
#   "that's",
#   'been',
#   'lost.',
#   'i',
#   'pledge',
#   'in',
#   'their',
#   'honor',
#   'that',
#   'we',
#   'will',
#   'develop',
#   'a',
#   'vaccine,',
#   'and…'],
#  ['rt',
#   '@tvnewshq:',
#   'president',
#   'trump',
#   'says',
#   'the',
#   'press',
#   '“should',
#   'be',
#   'ashamed',
#   'of',
#   'themselves”',
#   'for',
#   'ignoring',
#   'hunter',
#   'biden',
#   'allegedly',
#   'using',
#   'his',
#   'father’s',
#   'offic…'],
#  ['rt',
#   '@whitehouse:',
#   'president',
#   '@realdonaldtrump:',
#   '"we\'re',
#   'asking',
#   'everybody',
#   'that',
#   'when',
#   'you',
#   'are',
#   'not',
#   'able',
#   'to',
#   'socially',
#   'distance,',
#   'wear',
#   'a',
#   'mask."',
#   'https://…'],
#  ['really',
#   'big',
#   'jobs',
#   'report.',
#   'great',
#   'going',
#   'president',
#   'trump',
#   '(kidding',
#   'but',
#   'true)!'],
#  ['https://t.co/b4h105kvss'],
#  ['https://t.co/6bvrmg0yco'],
#  ['rt',
#   '@realdonaldtrump:',
#   'congressman',
#   '@lancegooden',
#   'has',
#   'done',
#   'a',
#   'wonderful',
#   'job',
#   'for',
#   'the',
#   'people',
#   'of',
#   'texas',
#   'while',
#   'supporting',
#   'our',
#   '#maga',
#   'agenda.',
#   'he',
#   'contin…'],
#  ['https://t.co/gvipuyttzg'],
#  ['rt',
#   '@timmurtaugh:',
#   'question',
#   'of',
#   'the',
#   'day',
#   'for',
#   'joe',
#   'biden',
#   'since',
#   'you’ll',
#   'be',
#   'speaking',
#   'with',
#   'virginia',
#   'democrats',
#   'today,',
#   'do',
#   'you',
#   'think',
#   'gov.',
#   'ralph',
#   'northa…'],
#  ['rt',
#   '@grovernorquist:',
#   'video:',
#   'yes,',
#   'biden',
#   'will',
#   'ban',
#   'fracking.',
#   'he',
#   'admits',
#   'it',
#   'on',
#   'camera',
#   'https://t.co/8b8xioikqv'],
#  ['rt',
#   '@tvnewshq:',
#   'president',
#   'trump',
#   'says',
#   'the',
#   'questions',
#   'that',
#   'the',
#   'media',
#   'ask',
#   'to',
#   'joe',
#   'biden',
#   '"were',
#   'meant',
#   'for',
#   'a',
#   'child."',
#   'https://t.co/sn9zsnecxn'],
#  ['rt',
#   '@timmurtaugh:',
#   'they',
#   'think',
#   'people',
#   'won’t',
#   'check',
#   'the',
#   'makeup',
#   'of',
#   'the',
#   'polls.',
#   'when',
#   'you',
#   'start',
#   'with',
#   'only',
#   '24%',
#   'of',
#   'respondents',
#   'being',
#   'republican,',
#   'what…'],
#  ['rt', '@erictrump:', 'jupiter', 'florida!!!', 'https://t.co/pjcbahdw1y'],
#  ['rt',
#   '@tvnewshq:',
#   'fox’s',
#   '@greggutfeld',
#   'on',
#   'atlantic’s',
#   'story:',
#   '“don’t',
#   'you',
#   'find',
#   'it',
#   'the',
#   'least',
#   'bit',
#   'questionable',
#   'that',
#   'the',
#   'biden',
#   'campaign',
#   '-',
#   'perhaps',
#   'the',
#   's…'],
#  ['rt',
#   '@senthomtillis:',
#   "i'm",
#   'proud',
#   'congress',
#   'could',
#   'come',
#   'together',
#   'to',
#   'make',
#   'necessary',
#   'fixes',
#   'to',
#   'the',
#   '#paycheckprotectionprogram.',
#   'these',
#   'changes',
#   'will',
#   'pro…'],
#  ['rt',
#   '@nasa:',
#   '"american',
#   'astronauts',
#   'on',
#   'american',
#   'rockets',
#   'from',
#   'american',
#   'soil,',
#   'showing',
#   'you',
#   'what',
#   'americans',
#   'can',
#   'do',
#   'when',
#   'we',
#   'come',
#   'together',
#   'as',
#   'a',
#   'team."…'],
#  ['rt',
#   '@realdonaldtrump:',
#   '.@louiegohmerttx1',
#   'is',
#   'a',
#   'fantastic',
#   'republican',
#   'from',
#   'the',
#   'great',
#   'state',
#   'of',
#   'texas!',
#   'he',
#   'fully',
#   'supports',
#   'our',
#   '#maga',
#   'and',
#   '#kag',
#   'agenda…'],
#  ['rt',
#   '@paulsperry_:',
#   'debuting',
#   'next',
#   'month:',
#   '"the',
#   'plot',
#   'against',
#   'the',
#   'president"',
#   'watch',
#   'the',
#   'trailer',
#   '...',
#   'https://t.co/quvpfgzm1d'],
#  ['winners', 'all!', 'https://t.co/2r5qutk0w8'],
#  ['rt',
#   '@donaldjtrumpjr:',
#   '.@kimstrassel',
#   'has',
#   'a',
#   'must-share',
#   'column',
#   'in',
#   'the',
#   'wsj',
#   'today',
#   'on',
#   'joe',
#   'biden’s',
#   'radical',
#   'left',
#   'climate',
#   'plan.',
#   'read',
#   'it',
#   'so',
#   'you',
#   'finally…'],
#  ['if',
#   'the',
#   'wall',
#   'street',
#   'journal',
#   '“editorial”',
#   'writers',
#   'had',
#   'called,',
#   'as',
#   'they',
#   'should',
#   'have,',
#   'they',
#   'would',
#   'have',
#   'easily',
#   'found',
#   'that',
#   'i',
#   'was',
#   '“not',
#   'happy',
#   'with',
#   'the',
#   'georgia',
#   'governor',
#   'on',
#   'tuesday',
#   'night.”',
#   'you',
#   'said',
#   'the',
#   'opposite,',
#   'and',
#   'got',
#   'it',
#   'wrong',
#   'as',
#   'you',
#   'often',
#   'do!'],
#  ['rt',
#   '@whitehouse:',
#   'live:',
#   'potus',
#   'participates',
#   'in',
#   'a',
#   'roundtable',
#   'https://t.co/bbzgcz76ad'],
#  ['rt',
#   '@redstate:',
#   'ouch!',
#   'three',
#   'astronauts',
#   'endorse',
#   "az's",
#   'gop',
#   'senator',
#   'over',
#   'her',
#   'astronaut',
#   'senate',
#   'challenger',
#   'https://t.co/xfdconhl0y'],
#  ['rt',
#   '@bucksexton:',
#   'a',
#   'reminder',
#   'that',
#   'those',
#   'who',
#   'pander',
#   'and',
#   'bow',
#   'to',
#   'the',
#   'mob',
#   'will',
#   'still',
#   'be',
#   'threatened',
#   'and',
#   'humiliated',
#   'by',
#   'it⬇️'],
#  ['https://t.co/m9kcwfeya7'],
#  ['rt',
#   '@whitehouse:',
#   '"you',
#   'eliminate',
#   'police',
#   'officers,',
#   'you',
#   'will',
#   'have',
#   'chaos,',
#   'crime,',
#   'and',
#   'anarchy',
#   'in',
#   'the',
#   'streets."',
#   'https://t.co/kkvfxhct1o'],
#  ['rt',
#   '@sbajovita:',
#   'the',
#   'paycheck',
#   'protection',
#   'program',
#   'has',
#   'helped',
#   'save',
#   'nearly',
#   '5',
#   'million',
#   'small',
#   'businesses',
#   'and',
#   '51',
#   'million',
#   'jobs,',
#   'making',
#   'it',
#   'one',
#   'of',
#   'the…'],
#  ['“defunding',
#   'police',
#   'would',
#   'be',
#   'good',
#   'for',
#   'robbers',
#   '&amp;',
#   'rapists.”',
#   '@senbillcassidy'],
#  ['big',
#   'demand!',
#   'starting',
#   'up',
#   'again',
#   'soon,',
#   'maybe',
#   'next',
#   'week!',
#   'https://t.co/tonlagl5fz'],
#  ['rt',
#   '@wesbury:',
#   'texas',
#   'has',
#   'a',
#   'decline',
#   'in',
#   'new',
#   'cases',
#   'as',
#   'well,',
#   'and',
#   'it’s',
#   'hospital',
#   'icus',
#   'are',
#   'at',
#   '87%',
#   'of',
#   'capacity.',
#   'like',
#   'florida,',
#   'things',
#   'look',
#   'better.',
#   'o…'],
#  ['rt',
#   '@senthomtillis:',
#   'i’m',
#   'proud',
#   'of',
#   'the',
#   'work',
#   'we',
#   'accomplished',
#   'in',
#   'the',
#   'fy2021',
#   '#ndaa',
#   'on',
#   'behalf',
#   'of',
#   'our',
#   'servicemembers,',
#   'including',
#   'securing',
#   'the',
#   'second…'],
#  ['new',
#   'york',
#   'city',
#   'indoor',
#   'dining',
#   'to',
#   'reopen',
#   'on',
#   'september',
#   '30,',
#   'at',
#   '25%',
#   'capacity.',
#   'a',
#   'step',
#   'in',
#   'the',
#   'right',
#   'direction,',
#   'but',
#   'should',
#   'go',
#   'faster!'],
#  ['they',
#   'went',
#   'for',
#   'a',
#   'coup.',
#   'almost',
#   'destroyed',
#   'our',
#   'country.',
#   'you',
#   'had',
#   'the',
#   'right',
#   'president',
#   'at',
#   'the',
#   'right',
#   'moment.',
#   'current',
#   'voters,',
#   'remember',
#   'this',
#   'when',
#   'you',
#   'vote!',
#   'https://t.co/w2s8ldiru0'],
#  ['sending',
#   'out',
#   '80',
#   'million',
#   'ballots',
#   'to',
#   'people',
#   'who',
#   'aren’t',
#   'even',
#   'asking',
#   'for',
#   'a',
#   'ballot',
#   'is',
#   'unfair',
#   'and',
#   'a',
#   'total',
#   'fraud',
#   'in',
#   'the',
#   'making.',
#   'look',
#   'at',
#   'what’s',
#   'going',
#   'on',
#   'right',
#   'now!'],
#  ['rt', '@realdonaldtrump:', 'make', 'america', 'great', 'again!'],
#  ['obama',
#   'worked',
#   'harder',
#   'for',
#   'hillary',
#   'clinton',
#   'and',
#   'the',
#   'losing',
#   'clinton',
#   'campaign',
#   'than',
#   'she',
#   'worked',
#   'for',
#   'herself!',
#   'now',
#   'he’s',
#   'working',
#   'with',
#   'sleepy',
#   'joe',
#   '-',
#   'will',
#   'be',
#   'same',
#   'result.',
#   'maga',
#   'is',
#   'energized',
#   'like',
#   'never',
#   'before!'],
#  ['obama',
#   'is',
#   'lucky',
#   'he',
#   'ran',
#   'against',
#   '@mittromney,',
#   'a',
#   'man',
#   'with',
#   'very',
#   'little',
#   'talent',
#   'or',
#   'political',
#   'skill,',
#   'as',
#   'opposed',
#   'to',
#   'someone',
#   'who',
#   'knows',
#   'how',
#   'to',
#   'fight',
#   'and',
#   'win!'],
#  ['rt',
#   '@realdonaldtrump:',
#   'the',
#   'fake',
#   'news',
#   'media',
#   'is',
#   'trying',
#   'to',
#   'portray',
#   'the',
#   'portland',
#   'and',
#   'seattle',
#   '“protesters”',
#   'as',
#   'wonderful,',
#   'sweet',
#   'and',
#   'innocent',
#   'people…'],
#  ['rt',
#   '@realdonaldtrump:',
#   '....would',
#   'destroy',
#   'our',
#   'american',
#   'cities,',
#   'and',
#   'worse,',
#   'if',
#   'sleepy',
#   'joe',
#   'biden,',
#   'the',
#   'puppet',
#   'of',
#   'the',
#   'left,',
#   'ever',
#   'won.',
#   'markets',
#   'would…'],
#  ['rt',
#   '@realdonaldtrump:',
#   'so',
#   'disgusting',
#   'to',
#   'watch',
#   'twitter’s',
#   'so-called',
#   '“trending”,',
#   'where',
#   'sooo',
#   'many',
#   'trends',
#   'are',
#   'about',
#   'me,',
#   'and',
#   'never',
#   'a',
#   'good',
#   'one.',
#   'they…'],
#  ['bob',
#   'woodward',
#   'had',
#   'my',
#   'quotes',
#   'for',
#   'many',
#   'months.',
#   'if',
#   'he',
#   'thought',
#   'they',
#   'were',
#   'so',
#   'bad',
#   'or',
#   'dangerous,',
#   'why',
#   'didn’t',
#   'he',
#   'immediately',
#   'report',
#   'them',
#   'in',
#   'an',
#   'effort',
#   'to',
#   'save',
#   'lives?',
#   'didn’t',
#   'he',
#   'have',
#   'an',
#   'obligation',
#   'to',
#   'do',
#   'so?',
#   'no,',
#   'because',
#   'he',
#   'knew',
#   'they',
#   'were',
#   'good',
#   'and',
#   'proper',
#   'answers.',
#   'calm,',
#   'no',
#   'panic!'],
#  ['democrats,',
#   'open',
#   'the',
#   'schools',
#   '(',
#   'safely),',
#   'now!',
#   'when',
#   'schools',
#   'are',
#   'closed,',
#   'let',
#   'the',
#   'money',
#   'follow',
#   'the',
#   'child',
#   '(family).',
#   'why',
#   'should',
#   'schools',
#   'be',
#   'paid',
#   'when',
#   'they',
#   'are',
#   'closed?',
#   'they',
#   'shouldn’t!'],
#  ['the',
#   'democrats',
#   'never',
#   'even',
#   'mentioned',
#   'the',
#   'words',
#   'law',
#   '&amp;',
#   'order',
#   'at',
#   'their',
#   'national',
#   'convention.',
#   'that’s',
#   'where',
#   'they',
#   'are',
#   'coming',
#   'from.',
#   'if',
#   'i',
#   'don’t',
#   'win,',
#   'america’s',
#   'suburbs',
#   'will',
#   'be',
#   'overrun',
#   'with',
#   'low',
#   'income',
#   'projects,',
#   'anarchists,',
#   'agitators,',
#   'looters',
#   'and,',
#   'of',
#   'course,',
#   '“friendly',
#   'protesters”.'],
#  ['https://t.co/ryhy1a2btn'],
#  ['homeland',
#   'security',
#   'is',
#   'not',
#   'leaving',
#   'portland',
#   'until',
#   'local',
#   'police',
#   'complete',
#   'cleanup',
#   'of',
#   'anarchists',
#   'and',
#   'agitators!'],
#  ['rt',
#   '@whitehouse:',
#   'president',
#   '@realdonaldtrump',
#   'is',
#   'working',
#   'to',
#   'ensure',
#   'that',
#   'america',
#   'produces',
#   'the',
#   'critical',
#   'goods',
#   'necessary',
#   'to',
#   'combat',
#   'covid-19',
#   'here…'],
#  ['yvette',
#   'herrell',
#   '(@yvette4congress)',
#   'is',
#   'a',
#   'proven',
#   'fighter',
#   'for',
#   'new',
#   'mexico!',
#   'she',
#   'strongly',
#   'supports',
#   'our',
#   'brave',
#   'law',
#   'enforcement,',
#   'life',
#   'and',
#   'the',
#   'second',
#   'amendment.',
#   'strong',
#   'on',
#   'the',
#   'border',
#   'and',
#   'trade,',
#   'yvette',
#   'has',
#   'my',
#   'complete',
#   'and',
#   'total',
#   'endorsement!',
#   '#nm02',
#   'https://t.co/77hjyfvwab'],
#  ['rt',
#   '@varneyco:',
#   'stu:',
#   '"are',
#   'you',
#   'ready',
#   'for',
#   'the',
#   'extraordinary',
#   'turmoil',
#   'that',
#   'a',
#   'joe',
#   '#biden',
#   'win',
#   'would',
#   'bring',
#   'on?"',
#   '#democrats',
#   '#2020election',
#   '#varneyco',
#   'h…'],
#  ['rt',
#   '@varneyco:',
#   'on',
#   'wednesday,',
#   'major',
#   'big',
#   '#tech',
#   'leaders',
#   'are',
#   'meeting',
#   'with',
#   'congress',
#   'to',
#   'discuss',
#   'potential',
#   '#regulations.',
#   'we',
#   'asked',
#   '@repkenbuck',
#   '-',
#   'wha…'],
#  ['if',
#   'joe',
#   'biden',
#   'is',
#   'elected,',
#   'far-left',
#   'lunatics',
#   'won’t',
#   'just',
#   'be',
#   'running',
#   'failed',
#   'dem',
#   'cities—they',
#   'will',
#   'be',
#   'running',
#   'the',
#   'department',
#   'of',
#   'justice,',
#   'the',
#   'department',
#   'of',
#   'homeland',
#   'security,',
#   'and',
#   'the',
#   'u.s.',
#   'supreme',
#   'court.',
#   'no',
#   'city,',
#   'town',
#   'or',
#   'suburb',
#   'will',
#   'be',
#   'safe.',
#   'on',
#   'november',
#   '3rd,',
#   'your',
#   'vote',
#   'will',
#   'save',
#   'america!',
#   'https://t.co/n8tzagbepr'],
#  ['rt',
#   '@realdonaldtrump:',
#   'i’m',
#   'with',
#   'you',
#   'all',
#   'the',
#   'way,',
#   'thank',
#   'you!',
#   'https://t.co/jl15lh7i7a'],
#  ['rt',
#   '@nikkihaley:',
#   '"look',
#   'at',
#   'the',
#   'difference',
#   'between',
#   'biden',
#   '&amp;',
#   'pres',
#   'trump.',
#   'who',
#   'is',
#   'the',
#   'person',
#   'that',
#   'moved',
#   'the',
#   'embassy',
#   'from',
#   'tel',
#   'aviv',
#   'to',
#   'jerusalem?',
#   'wh…'],
#  ['https://t.co/pf6ekcrwd3'],
#  ['just',
#   'landed',
#   'in',
#   'the',
#   'great',
#   'state',
#   'of',
#   'texas!',
#   'https://t.co/z9ljiu0uec'],
#  ['wow!', 'do', 'you', 'believe', 'this!?', 'https://t.co/ezbm1z0fki'],
#  ['rt',
#   '@abc13news:',
#   'new',
#   'jersey',
#   'postal',
#   'employee',
#   'accused',
#   'of',
#   'dumping',
#   '1,800',
#   'pieces',
#   'of',
#   'mail.',
#   'the',
#   'mail',
#   'included',
#   '99',
#   'ballots',
#   'for',
#   'the',
#   'upcoming',
#   'election.…'],
#  ['rt',
#   '@abc13news:',
#   'nearly',
#   '50,000',
#   'voters',
#   'received',
#   'wrong',
#   'ballots',
#   'in',
#   'ohio!',
#   'does',
#   'you',
#   'feel',
#   'safe',
#   'mailing',
#   'in',
#   'your',
#   'ballot?',
#   'read',
#   'more:',
#   'https://t.co/m8l…'],
#  ['rt',
#   '@wtkr3:',
#   '#texas',
#   'mayoral',
#   'candidate',
#   'arrested',
#   'for',
#   'voter',
#   'fraud,',
#   'allegedly',
#   'applied',
#   'for',
#   '84',
#   'ballots',
#   'https://t.co/jut0rkcmr6',
#   'https://t.co/grpyww3…'],
#  ['in',
#   'an',
#   'illegal',
#   'late',
#   'night',
#   'coup,',
#   'nevada’s',
#   'clubhouse',
#   'governor',
#   'made',
#   'it',
#   'impossible',
#   'for',
#   'republicans',
#   'to',
#   'win',
#   'the',
#   'state.',
#   'post',
#   'office',
#   'could',
#   'never',
#   'handle',
#   'the',
#   'traffic',
#   'of',
#   'mail-in',
#   'votes',
#   'without',
#   'preparation.',
#   'using',
#   'covid',
#   'to',
#   'steal',
#   'the',
#   'state.',
#   'see',
#   'you',
#   'in',
#   'court!',
#   'https://t.co/cnspingcy7'],
#  ['with',
#   'the',
#   'exception',
#   'of',
#   'new',
#   'york',
#   '&amp;',
#   'a',
#   'few',
#   'other',
#   'locations,',
#   'we’ve',
#   'done',
#   'much',
#   'better',
#   'than',
#   'most',
#   'other',
#   'countries',
#   'in',
#   'dealing',
#   'with',
#   'the',
#   'china',
#   'virus.',
#   'many',
#   'of',
#   'these',
#   'countries',
#   'are',
#   'now',
#   'having',
#   'a',
#   'major',
#   'second',
#   'wave.',
#   'the',
#   'fake',
#   'news',
#   'is',
#   'working',
#   'overtime',
#   'to',
#   'make',
#   'the',
#   'usa',
#   '(&amp;',
#   'me)',
#   'look',
#   'as',
#   'bad',
#   'as',
#   'possible!'],
#  ['rt', '@danscavino:', 'https://t.co/zsp7bttpkn'],
#  ['oklahoma,',
#   'we',
#   'need',
#   '@stephaniebice',
#   'in',
#   'congress!',
#   'she',
#   'delivers',
#   'for',
#   'our',
#   'teachers',
#   '&amp;',
#   'students,',
#   'and',
#   'she',
#   'will',
#   'always',
#   'protect',
#   'your',
#   '#2a',
#   '&amp;',
#   'energy',
#   'jobs,',
#   'unlike',
#   'her',
#   'opponent',
#   'who',
#   'votes',
#   'against',
#   'our',
#   'oil',
#   '&amp;',
#   'gas',
#   'industry.',
#   'stephanie',
#   'has',
#   'my',
#   'complete',
#   'and',
#   'total',
#   'endorsement!',
#   '#ok05',
#   'https://t.co/rwhcrmfayq'],
#  ['https://t.co/cmnugjngyj'],
#  ['rt',
#   '@realdonaldtrump:',
#   'fake',
#   'news',
#   'is',
#   'the',
#   'enemy',
#   'of',
#   'the',
#   'people!'],
#  ['https://t.co/h5baku6xws'],
#  ['rt',
#   '@jackturmaniii:',
#   'the',
#   'franklin',
#   'county',
#   'board',
#   'of',
#   'elections',
#   'announced',
#   'that',
#   '49,669',
#   'voters',
#   'in',
#   'the',
#   'county',
#   'received',
#   'an',
#   'incorrect',
#   'ballot.',
#   'in',
#   'a',
#   'sta…'],
#  ['rt',
#   '@teamtrump:',
#   'president',
#   '@realdonaldtrump:',
#   'we',
#   'achieved',
#   'record-low',
#   'unemployment',
#   'for',
#   'african',
#   'americans,',
#   'hispanic',
#   'americans,',
#   'asian',
#   'americans',
#   'a…'],
#  ['rt',
#   '@teamtrump:',
#   'president',
#   '@realdonaldtrump:',
#   'we',
#   'passed',
#   'the',
#   'largest',
#   'tax',
#   'cut',
#   'in',
#   'the',
#   'history',
#   'of',
#   'our',
#   'country',
#   'https://t.co/89zrfv1qe0'],
#  ['rt',
#   '@teamtrump:',
#   'president',
#   '@realdonaldtrump',
#   'from',
#   'his',
#   'pennsylvania',
#   'tele-rally:',
#   'getting',
#   'rid',
#   'of',
#   'fracking,',
#   'like',
#   'what',
#   'joe',
#   'biden',
#   'and',
#   'the',
#   'radical',
#   'de…'],
#  ['rt',
#   '@whitehouse:',
#   'live:',
#   'president',
#   '@realdonaldtrump',
#   'delivers',
#   'remarks',
#   'at',
#   'a',
#   'peaceful',
#   'protest',
#   'for',
#   'law',
#   '&amp;',
#   'order',
#   'https://t.co/blgvcjjnvx'],
#  ['@rebaforever58', 'yes.'],
#  ['rt',
#   '@whitehouse:',
#   'live:',
#   'president',
#   '@realdonaldtrump',
#   'holds',
#   'a',
#   'news',
#   'conference',
#   'https://t.co/qee0fvgqed'],
#  ['rt',
#   '@whitehouse:',
#   '"let',
#   'me',
#   'begin',
#   'by',
#   'sending',
#   "america's",
#   'deepest',
#   'sympathies',
#   'to',
#   'the',
#   'people',
#   'of',
#   'lebanon."',
#   'https://t.co/czitqk2a0s'],
#  ['rt',
#   '@loudobbs:',
#   'reopening',
#   'america:',
#   'president',
#   '@realdonaldtrump',
#   'says',
#   '‘we’re',
#   'not',
#   'shutting',
#   'down’',
#   'our',
#   'country',
#   'and',
#   'economy',
#   'again.',
#   '#maga',
#   '#americafir…'],
#  ['great',
#   'meeting',
#   'today',
#   'with',
#   'the',
#   'coronavirus',
#   'task',
#   'force',
#   'in',
#   'the',
#   'oval',
#   'office.',
#   'stay',
#   'informed',
#   'at:',
#   'https://t.co/p9j7kzsd7b.',
#   'https://t.co/nnnuhczolv'],
#  ['there',
#   'is',
#   'tremendous',
#   'lawlessness',
#   'in',
#   'america’s',
#   'liberal',
#   'cities.',
#   'would',
#   'be',
#   'so',
#   'easy',
#   'to',
#   'stop',
#   'but',
#   'they',
#   'have',
#   'a',
#   'clouded',
#   'vision',
#   'of',
#   'what',
#   'should',
#   'be',
#   'done.',
#   'they',
#   'are',
#   'indoctrinated',
#   'with',
#   'a',
#   'philosophy',
#   'which',
#   'will',
#   'never',
#   'work,',
#   'a',
#   'philosophy',
#   'which',
#   'would',
#   'destroy',
#   'america.',
#   'portland',
#   'would',
#   'be',
#   'the',
#   'norm!'],
#  ['i',
#   'will',
#   'be',
#   'interviewed',
#   'on',
#   '@foxandfriends',
#   'at',
#   '7:30',
#   'a.m.',
#   'enjoy!'],
#  ['rt',
# ...
#   'the',
#   'century',
#   'is',
#   'unfolding.',
#   'obamabiden',
#   'illegally',
#   'spied',
#   'on',
#   'the',
#   'trump',
#   'campaign,',
#   'both',
#   'before',
#   'and',
#   'after',
#   'the',
#   'election.',
#   'treason!',
#   'https://t.co/6xf1piwmno'],
#  ['rt',
#   '@repthomasmassie:',
#   'i’d',
#   'fire',
#   'him.',
#   'i',
#   'listened',
#   'to',
#   'his',
#   'testimony',
#   'in',
#   'the',
#   'scif.',
#   'he’s',
#   'a',
#   'leaker,',
#   'not',
#   'a',
#   'whistleblower.',
#   'vindman',
#   'was',
#   'upset',
#   'that',
#   '@rea…'],
#  ['rt',
#   '@trumpwarroom:',
#   'the',
#   'fbi',
#   'found',
#   '"no',
#   'derogatory',
#   'information"',
#   'about',
#   '@genflynn.',
#   'but',
#   'they',
#   'decided',
#   'to',
#   'crush',
#   'him',
#   'anyway.',
#   '"there',
#   'is',
#   'nothing',
#   'worse…'],
#  ['the',
#   'russia',
#   'hoax',
#   'is',
#   'the',
#   'biggest',
#   'political',
#   'scandal',
#   'in',
#   'american',
#   'history.',
#   'treason!!!',
#   'lets',
#   'see',
#   'how',
#   'it',
#   'ends????',
#   'https://t.co/vrsvdiqrsf'],
#  ['rt',
#   '@erinmperrine:',
#   '🚨🚨',
#   'tune',
#   'in',
#   'now',
#   '🚨🚨',
#   'tonight’s',
#   '@teamtrump',
#   'online!',
#   'has',
#   'two',
#   'of',
#   'the',
#   'best',
#   '—&gt;',
#   '@laraleatrump',
#   '&amp;',
#   '@kevinomccarthy',
#   'talking',
#   'about',
#   'slee…'],
#  ['rt',
#   '@teamtrump:',
#   'watch:',
#   'team',
#   'trump',
#   'online',
#   'with',
#   '@laraleatrump',
#   'and',
#   'house',
#   'gop',
#   'leader',
#   '@kevinmccarthy!',
#   '#teamtrump',
#   'text',
#   'trump',
#   'to',
#   '88022',
#   'https://t.c…'],
#  ['rt',
#   '@teamtrump:',
#   'tisa',
#   'clark,',
#   'ceo',
#   'of',
#   'j.d.',
#   'clark',
#   'professional',
#   'services,',
#   'credits',
#   'the',
#   '#paycheckprotectionprogram',
#   'for',
#   'allowing',
#   'her',
#   'to',
#   'keep',
#   'her',
#   'wor…'],
#  ['rt',
#   '@equipotrump:',
#   'as',
#   'trump',
#   'campaign',
#   'senior',
#   'advisor',
#   '@mercedesschlapp',
#   'said',
#   'today,',
#   'joe',
#   "biden's",
#   'plan',
#   'to',
#   'ease',
#   'sanctions',
#   'on',
#   'the',
#   'cuban',
#   'and',
#   'venezuel…'],
#  ['the',
#   'democrats',
#   'in',
#   'the',
#   'house',
#   'should',
#   'propose',
#   'a',
#   'very',
#   'simple',
#   'one',
#   'year',
#   'payroll',
#   'tax',
#   'cut.',
#   'great',
#   'for',
#   'the',
#   'middle',
#   'class,',
#   'great',
#   'for',
#   'the',
#   'usa!'],
#  ['rt',
#   '@mike_pence:',
#   'as',
#   'a',
#   'result',
#   'of',
#   'president',
#   '@realdonaldtrump’s',
#   'leadership,',
#   'every',
#   'state',
#   'lab',
#   'in',
#   'the',
#   'country',
#   'can',
#   'now',
#   'conduct',
#   'coronavirus',
#   'testing.…'],
#  ['https://t.co/lewobtmvuf'],
#  ['rt',
#   '@realdonaldtrump:',
#   'a',
#   'must',
#   'watch',
#   'for',
#   'the',
#   'good',
#   'of',
#   'our',
#   'democracy!',
#   'https://t.co/dve6z7sshw'],
#  ['thank', 'you', 'james!', 'https://t.co/ku1rmhmevk'],
#  ['.@foxnews',
#   'allows',
#   'more',
#   'negative',
#   'ads',
#   'on',
#   'me',
#   'than',
#   'practically',
#   'all',
#   'of',
#   'the',
#   'other',
#   'networks',
#   'combined.',
#   'not',
#   'like',
#   'the',
#   'old',
#   'days,',
#   'but',
#   'we',
#   'will',
#   'win',
#   'even',
#   'bigger',
#   'than',
#   '2016.',
#   'roger',
#   'ailes',
#   'was',
#   'the',
#   'greatest!'],
#  ['drain', 'the', 'swamp!', 'https://t.co/68m4sn7lld'],
#  ['rt',
#   '@lrihendry:',
#   'fascinating',
#   'paradox:',
#   'the',
#   'more',
#   'president',
#   'trump',
#   'gets',
#   'investigated,',
#   'the',
#   'more',
#   'crimes',
#   'are',
#   'exposed',
#   'involving',
#   'prominent',
#   'democrats.'],
#  ['rt',
#   '@marshablackburn:',
#   'how',
#   'can',
#   'we',
#   'trust',
#   'anything',
#   'in',
#   'the',
#   'house',
#   'democrats’',
#   'impeachment*',
#   'report?',
#   'their',
#   'lead',
#   'investigator,',
#   'adam',
#   'schiff,',
#   'fabrica…'],
#  ['rt',
#   '@tomfitton:',
#   'icymi,',
#   'because',
#   'of',
#   'dishonest',
#   'liberal',
#   'media',
#   'that',
#   'was',
#   'conspiring',
#   'with',
#   'pelosi-schiff',
#   'coup',
#   'cabal',
#   'to',
#   'try',
#   'to',
#   'destroy',
#   '@realdonaldtru…'],
#  ['rt',
#   '@marshablackburn:',
#   'this',
#   'is',
#   'a',
#   'solid',
#   'win',
#   'for',
#   'our',
#   'farmers',
#   'and',
#   'manufactures',
#   '–',
#   'china',
#   'will',
#   'be',
#   'purchasing',
#   '$200',
#   'billion',
#   'in',
#   'american',
#   'goods',
#   'and',
#   'ser…'],
#  ['rt',
#   '@marshablackburn:',
#   '.@sensanders,',
#   '@senwarren,',
#   '@senamyklobuchar,',
#   'and',
#   '@senatorbennet',
#   'are',
#   'spending',
#   'millions',
#   'of',
#   'dollars',
#   'to',
#   'defeat',
#   '@realdonaldt…'],
#  ['the',
#   'farmers',
#   'are',
#   'really',
#   'happy',
#   'with',
#   'the',
#   'new',
#   'china',
#   'trade',
#   'deal',
#   'and',
#   'the',
#   'soon',
#   'to',
#   'be',
#   'signed',
#   'deal',
#   'with',
#   'mexico',
#   'and',
#   'canada,',
#   'but',
#   'i',
#   'hope',
#   'the',
#   'thing',
#   'they',
#   'will',
#   'most',
#   'remember',
#   'is',
#   'the',
#   'fact',
#   'that',
#   'i',
#   'was',
#   'able',
#   'to',
#   'take',
#   'massive',
#   'incoming',
#   'tariff',
#   'money',
#   'and',
#   'use',
#   'it',
#   'to',
#   'help',
#   'them',
#   'get',
#   'through',
#   'the',
#   'tough',
#   'times!'],
#  ['rt',
#   '@senategop:',
#   '✓',
#   'signed',
#   '@realdonaldtrump',
#   'just',
#   'signed',
#   'the',
#   'phase',
#   'one',
#   'trade',
#   'agreement',
#   'with',
#   'china.',
#   'this',
#   'is',
#   'the',
#   'second',
#   'historic',
#   'trade',
#   'deal',
#   're…'],
#  ['rt',
#   '@whitehouse:',
#   'live:',
#   'president',
#   '@realdonaldtrump',
#   'holds',
#   'a',
#   'news',
#   'conference',
#   'https://t.co/oesn53myzq'],
#  ['rt',
#   '@realdonaldtrump:',
#   'thank',
#   'you',
#   '@govbilllee',
#   'and',
#   '@marialeetn.',
#   'my',
#   'administration',
#   'will',
#   'always',
#   'be',
#   'there',
#   'for',
#   'the',
#   'great',
#   'people',
#   'of',
#   'tennessee.',
#   'toget…'],
#  ['rt',
#   '@seanhannity:',
#   '@realdonaldtrump',
#   'donates',
#   'his',
#   'quarterly',
#   'salary',
#   'to',
#   'help',
#   'fight',
#   'coronavirus,',
#   'find',
#   'vaccine',
#   'https://t.co/k6ihtvlkls'],
#  ['so',
#   'much',
#   'of',
#   'the',
#   'lamestream',
#   'media',
#   'is',
#   'writing',
#   'and',
#   'broadcasting',
#   'stories',
#   'with',
#   'facts',
#   'that',
#   'are',
#   'made',
#   'up',
#   'and',
#   'knowingly',
#   'wrong.',
#   'they',
#   'are',
#   'doing',
#   'it',
#   'by',
#   'quoting',
#   'unnamed',
#   'sources',
#   'that',
#   'simply',
#   'do',
#   'not',
#   'exist.',
#   'these',
#   'are',
#   'very',
#   'dangerous',
#   '&amp;',
#   'corrupt',
#   'people,',
#   'who',
#   'will',
#   'do',
#   'anything',
#   'to',
#   'win.',
#   'name',
#   'your',
#   'sources!'],
#  ['rt',
#   '@dancrenshawtx:',
#   'this',
#   'is',
#   'dangerous,',
#   'counterproductive,',
#   'and',
#   'deeply',
#   'irrational.',
#   '“defund',
#   'the',
#   'police”',
#   'is',
#   'not',
#   'a',
#   'call',
#   'from',
#   'the',
#   'fringes',
#   'of',
#   'the',
#   'f…'],
#  ['pelosi',
#   'doesn’t',
#   'want',
#   'to',
#   'hand',
#   'over',
#   'the',
#   'articles',
#   'of',
#   'impeachment,',
#   'which',
#   'were',
#   'fraudulently',
#   'produced',
#   'by',
#   'corrupt',
#   'politicians',
#   'like',
#   'shifty',
#   'schiff',
#   'in',
#   'the',
#   'first',
#   'place,',
#   'because',
#   'after',
#   'all',
#   'of',
#   'these',
#   'years',
#   'of',
#   'investigations',
#   'and',
#   'persecution,',
#   'they',
#   'show',
#   'no',
#   'crimes',
#   'and',
#   'are',
#   'a',
#   'joke',
#   'and',
#   'a',
#   'scam!'],
#  ['rt',
#   '@senatemajldr:',
#   'there',
#   'will',
#   'be',
#   'no',
#   'haggling',
#   'with',
#   'the',
#   'house',
#   'over',
#   'senate',
#   'procedure.',
#   'we',
#   'will',
#   'not',
#   'cede',
#   'our',
#   'authority',
#   'to',
#   'try',
#   'this',
#   'impeachment.',
#   't...'],
#  ['thank', 'you', 'michael.', 'you', 'also!', 'https://t.co/vfi6nhj3zg'],
#  ['at',
#   'least',
#   'they',
#   'admit',
#   'it.',
#   'the',
#   'failing',
#   '@nytimes',
#   '&amp;',
#   '@washingtonpost',
#   'never',
#   'correct',
#   'their',
#   'fake',
#   'reporting!',
#   'https://t.co/3auka4826k'],
#  ['wow!',
#   'sleepy',
#   'joe',
#   'doesn’t',
#   'know',
#   'where',
#   'he',
#   'is,',
#   'or',
#   'what',
#   'he’s',
#   'doing.',
#   'honestly,',
#   'i',
#   'don’t',
#   'think',
#   'he',
#   'even',
#   'knows',
#   'what',
#   'office',
#   "he's",
#   'running',
#   'for!',
#   'https://t.co/454v9gfpgf'],
#  ['getting',
#   'ready',
#   'to',
#   'land',
#   'in',
#   'florida.',
#   'big',
#   'crowd!',
#   'live',
#   'on',
#   'various',
#   'networks:',
#   '@oann,',
#   '@cspan,',
#   '@newsmax',
#   'and',
#   'others!!!'],
#  ['rt', '@pianorama:', 'uncouth', 'is', 'too', 'polite.', '#pelositantrum'],
#  ['rt',
#   '@realdonaldtrump:',
#   '.@billhagertytn,',
#   'an',
#   'outstanding',
#   'man',
#   'and',
#   'one',
#   'of',
#   'the',
#   'best',
#   'ambassadors',
#   'ever',
#   '(japan),',
#   'is',
#   'running',
#   'an',
#   'excellent',
#   'campaign',
#   'for…'],
#  ['rt',
#   '@jsolomonreports:',
#   'breaking:',
#   'mueller’s',
#   'team',
#   'was',
#   'told',
#   'by',
#   'key',
#   'witness',
#   'in',
#   '2018',
#   'that',
#   'russia',
#   'collusion',
#   'evidence',
#   'found',
#   'in',
#   'ukraine',
#   'was',
#   'fabricate…'],
#  ['“mail-vote',
#   'madness',
#   'in',
#   'pennsylvania',
#   '-',
#   'the',
#   'swing',
#   'state',
#   'is',
#   'heading',
#   'toward',
#   'an',
#   'election',
#   'crackup',
#   'that',
#   'could',
#   'draw',
#   'the',
#   'entire',
#   'country',
#   'into',
#   'a',
#   'legal',
#   'brawl.”',
#   '.@governortomwolf',
#   'of',
#   'pennsylvania',
#   'should',
#   'not',
#   'be',
#   'allowed',
#   'to',
#   'defraud',
#   'the',
#   'people',
#   'of',
#   'the',
#   'united',
#   'states!',
#   'https://t.co/gmq1v2nes3'],
#  ['rt',
#   '@erinmperrine:',
#   'morning',
#   'in',
#   'america',
#   '🇺🇸',
#   'https://t.co/ac9lpvcun4'],
#  ['https://t.co/vizkbzm7sp'],
#  ['it',
#   'was',
#   'great',
#   'to',
#   'be',
#   'back',
#   'in',
#   'my',
#   'home',
#   'state',
#   'of',
#   'florida',
#   'to',
#   'make',
#   'my',
#   'official',
#   'return',
#   'to',
#   'the',
#   'campaign',
#   'trail.',
#   'i',
#   'am',
#   'energized',
#   'by',
#   'your',
#   'prayers,',
#   'humbled',
#   'by',
#   'your',
#   'support,',
#   'and',
#   'absolutely',
#   'determined',
#   'to',
#   'finish',
#   'what',
#   'we',
#   'started',
#   'and',
#   'make',
#   'america',
#   'greater',
#   'than',
#   'ever',
#   'before!',
#   'https://t.co/xrqg0kpduo'],
#  ['we',
#   'have',
#   'now',
#   'learned',
#   'for',
#   'sure',
#   'that',
#   'the',
#   'democrats',
#   'don’t',
#   'want',
#   'anything',
#   'to',
#   'do',
#   'with',
#   'crazy',
#   'bernie.',
#   'rigged?',
#   'first',
#   '@amyklobuchar',
#   '&amp;',
#   '@petebuttigieg',
#   'quit',
#   'the',
#   'race',
#   '&amp;',
#   'come',
#   'out',
#   'for',
#   'sleepy',
#   'joe',
#   'before',
#   'super',
#   'tuesday.',
#   'pocahontas',
#   'says',
#   'no',
#   '&amp;',
#   'quits',
#   'race',
#   'after',
#   'election,',
#   'thereby',
#   'depriving',
#   'bernie',
#   'of',
#   'at..'],
#  ['thank', 'you', '@marklevinshow!', 'https://t.co/gjsnm0luqh'],
#  ['new',
#   'york',
#   'state',
#   'is',
#   'killing',
#   'small',
#   'businesses.',
#   'let',
#   'them',
#   'properly',
#   'open!',
#   '@foxandfriends'],
#  ['rt',
#   '@scavino45:',
#   '“@realdonaldtrump',
#   'signs',
#   'phase',
#   'one',
#   'trade',
#   'deal',
#   'with',
#   'china”',
#   'https://t.co/xogyw8zvwk'],
#  ['rt',
#   '@marcorubio:',
#   'natl',
#   'security',
#   'officials',
#   'gave',
#   'a',
#   'compelling',
#   'briefing',
#   'to',
#   'senators',
#   'just',
#   'now.',
#   'they',
#   'answered',
#   'every',
#   'important',
#   'question.',
#   'anyone',
#   'w...'],
#  ['rt',
#   '@marcorubio:',
#   'former',
#   'obama',
#   'officials',
#   '&amp,',
#   'their',
#   'media',
#   'protectors',
#   'can',
#   'howl',
#   'all',
#   'they',
#   'want.it’s',
#   'a',
#   'fact',
#   'that',
#   'as',
#   'part',
#   'of',
#   '#irandeal',
#   'they',
#   'delive...'],
#  ['great!', 'https://t.co/9qbyhxrlus'],
#  ['heading',
#   'to',
#   'the',
#   'great',
#   'state',
#   'of',
#   'virginia',
#   'now,',
#   'will',
#   'be',
#   'there',
#   'shortly.',
#   'the',
#   '#usnscomfort',
#   'is',
#   '“loaded',
#   'to',
#   'the',
#   'gills”',
#   'at',
#   'naval',
#   'station',
#   'norfolk,',
#   'departing',
#   'for',
#   'new',
#   'york',
#   'city',
#   'this',
#   'afternoon.',
#   'https://t.co/1zsuweox7x'],
#  ['rt',
#   '@scavino45:',
#   '“as',
#   'long',
#   'as',
#   'i',
#   'am',
#   'president',
#   'of',
#   'the',
#   'united',
#   'states,',
#   'iran',
#   'will',
#   'never',
#   'be',
#   'allowed',
#   'to',
#   'have',
#   'a',
#   'nuclear',
#   'weapon.”@potus',
#   '@realdonaldtru...'],
#  ['rt',
#   '@teamtrump:',
#   'watch:',
#   '@ivankatrump',
#   'on',
#   'the',
#   'blue',
#   'collar',
#   'boom',
#   'and',
#   'rising',
#   'wages',
#   'under',
#   '@realdonaldtrump!',
#   'https://t.co/dsjartyvkt'],
#  ['rt',
#   '@gopchairwoman:',
#   'instead',
#   'of',
#   'attacking',
#   '@realdonaldtrump',
#   'with',
#   'iranian',
#   'talking',
#   'points',
#   'about',
#   '“needless',
#   'provocations,”',
#   'pelosi',
#   'should',
#   'be',
#   'suppor...'],
#  ['one',
#   'of',
#   'the',
#   'greatest',
#   'trade',
#   'deals',
#   'ever',
#   'made!',
#   'also',
#   'good',
#   'for',
#   'china',
#   'and',
#   'our',
#   'long',
#   'term',
#   'relationship.',
#   '250',
#   'billion',
#   'dollars',
#   'will',
#   'be',
#   'coming',
#   'back',
#   'to',
#   'our',
#   'country,',
#   'and',
#   'we',
#   'are',
#   'now',
#   'in',
#   'a',
#   'great',
#   'position',
#   'for',
#   'a',
#   'phase',
#   'two',
#   'start.',
#   'there',
#   'has',
#   'never',
#   'been',
#   'anything',
#   'like',
#   'this',
#   'in',
#   'u.s.',
#   'history!',
#   'usmca',
#   'next!'],
#  ['rt',
#   '@danscavino:',
#   'sleepy',
#   'joe💤in',
#   'st.',
#   'louis,',
#   'missouri',
#   'today:',
#   '“we',
#   'can',
#   'only',
#   're-elect',
#   '@realdonaldtrump.”',
#   '#kag2020landslidevictory🇺🇸',
#   'https://t.co…'],
#  ['rt', '@jackposobiec:', 'blue', 'angels', 'dc', 'https://t.co/2xdzmdl94n'],
#  ['joe',
#   'biden’s',
#   'agenda',
#   'would',
#   'be',
#   'a',
#   'catastrophe',
#   'for',
#   'florida',
#   'seniors.',
#   'for',
#   'years,',
#   'biden',
#   'tried',
#   'to',
#   'cut',
#   'social',
#   'security',
#   'and',
#   'medicare.',
#   'now',
#   'biden',
#   'is',
#   'pledging',
#   'mass',
#   'amnesty',
#   'and',
#   'federal',
#   'healthcare',
#   'for',
#   'illegal',
#   'aliens—decimating',
#   'medicare',
#   'and',
#   'destroying',
#   'social',
#   'security...https://t.co/gghp0nvpee'],
#  ['no,',
#   'i',
#   'think',
#   'amash',
#   'would',
#   'make',
#   'a',
#   'wonderful',
#   'candidate,',
#   'especially',
#   'since',
#   'he',
#   'is',
#   'way',
#   'behind',
#   'in',
#   'his',
#   'district',
#   'and',
#   'has',
#   'no',
#   'chance',
#   'of',
#   'maintaining',
#   'his',
#   'congressional',
#   'seat.',
#   'he',
#   'almost',
#   'always',
#   'votes',
#   'for',
#   'the',
#   'do',
#   'nothing',
#   'dems',
#   'anyway.',
#   'i',
#   'like',
#   'him',
#   'even',
#   'more',
#   'than',
#   'jill',
#   'stein!',
#   'https://t.co/v8kutnfvij'],
#  ['“for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'history,',
#   'police',
#   'organizations',
#   '&amp;',
#   'national',
#   'security',
#   'organizations',
#   'were',
#   'used',
#   'to',
#   'spy',
#   'on',
#   'a',
#   'campaign,',
#   '&amp;',
#   'there',
#   'was',
#   'no',
#   'basis',
#   'for',
#   'it.',
#   'the',
#   'media',
#   'largely',
#   'drove',
#   'that,',
#   '&amp;',
#   'claims',
#   'were',
#   'made',
#   'that',
#   'could',
#   'have',
#   'affected',
#   'the',
#   'election',
#   'of',
#   'the',
#   'president.”',
#   'a.g.',
#   'bill',
#   'barr',
#   '@bretbaier'],
#  ['rt',
#   '@realdonaldtrump:',
#   'wall',
#   'is',
#   'going',
#   'up',
#   'fast.',
#   '184',
#   'miles',
#   'as',
#   'of',
#   'today!'],
#  ['rt',
#   '@realdonaldtrump:',
#   'the',
#   'obama',
#   'administration',
#   'is',
#   'turning',
#   'out',
#   'to',
#   'be',
#   'one',
#   'of',
#   'the',
#   'most',
#   'corrupt',
#   'and',
#   'incompetent',
#   'in',
#   'u.s.',
#   'history.',
#   'remember,',
#   'he',
#   'an…'],
#  ['rt',
#   '@realdonaldtrump:',
#   'lacy',
#   'will',
#   'do',
#   'a',
#   'great',
#   'job.',
#   'omar',
#   'is',
#   'a',
#   'corrupt',
#   'disaster!'],
#  ['yes!', 'https://t.co/kyjgtlfo5y'],
#  ['rt',
#   '@lrihendry:',
#   'wow!',
#   'mr',
#   'president,',
#   'this',
#   'woman,',
#   'lynn,',
#   'has',
#   'never',
#   'voted',
#   'in',
#   'her',
#   'entire',
#   'life',
#   'until',
#   'she',
#   'was',
#   '59',
#   'years',
#   'old.',
#   'at',
#   'the',
#   'time',
#   'she',
#   'voted',
#   'fo…'],
#  ['chicago‘s',
#   'fraternal',
#   'order',
#   'of',
#   'police',
#   'endorses',
#   'donald',
#   'trump',
#   'for',
#   'reelection',
#   'https://t.co/ksdjk2rufh',
#   'via',
#   '@breitbartnews.',
#   'thank',
#   'you',
#   'to',
#   'john',
#   'catanzara',
#   'and',
#   'chicago’s',
#   'fop.',
#   'i',
#   'will',
#   'never',
#   'let',
#   'you',
#   'down!'],
#  ['rt',
#   '@dbongino:',
#   'president',
#   "trump's",
#   'best',
#   'week',
#   'ever',
#   'continues',
#   '👇https://t.co/bbffdsve4p'],
#  ['rt',
#   '@whitehouse:',
#   'president',
#   '@realdonaldtrump',
#   'gives',
#   'an',
#   'update',
#   'on',
#   'tropical',
#   'storm',
#   'isaias:',
#   'https://t.co/5snaynzdef'],
#  ['thank', 'you', '@senatortimscott!', 'https://t.co/7sp0mj1al0'],
#  ...]

# %%
pattern
# Out:
# 'stock|market|economy'

# %%
keywords = ['stock', 'market', 'economy', 'company', 'bull']
pattern = '|'.join(keywords)
new = tweet_df2['text'].str.lower().str.contains(pattern, case=False) 

tweet_df_filtered = tweet_df2[new]
tweet_df_filtered.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)
# Out:
#                         id                                               text  \
# 215    1287951596832391169  RT @realDonaldTrump: ....would destroy our Ame...
# 250    1290784742238027777  RT @LouDobbs: Reopening America: President @re...
# 343     891343645529567232    U.S. Stock Market up almost 20% since Election!
# 475    1318898380421083137  Remember, BIDEN is going to raise your taxes a...
# 501    1255831769590435840  RT @mitchellvii: The economy is going to do so...
# ...                    ...                                                ...
# 54339  1083001986331672580  Our Country is doing so well in so many ways. ...
# 54345  1082623264877432837  Economic numbers looking REALLY good. Can you ...
# 54376  1081175076727345152  As I have stated many times, if the Democrats ...
# 54411  1215285845336502272  STOCK MARKET AT ALL-TIME HIGH! HOW ARE YOUR 40...
# 54418  1213585005986959361  As hard as I work, &amp, as successful as our ...
#
#       isRetweet isDeleted              device  favorites  retweets  \
# 215           t         f  Twitter for iPhone          0     22688
# 250           t         f  Twitter for iPhone          0      7241
# 343           f         f  Twitter for iPhone      88855     17565
# 475           f         f  Twitter for iPhone     262641     56660
# 501           t         t  Twitter for iPhone          0      5824
# ...         ...       ...                 ...        ...       ...
# 54339         f         f  Twitter for iPhone     144074     27610
# 54345         f         f  Twitter for iPhone     109157     20925
# 54376         f         f  Twitter for iPhone     147477     29768
# 54411         f         t  Twitter for iPhone      38281      7685
# 54418         f         f  Twitter for iPhone     255804     43544
#
#                       date                                    word_and_scores  \
# 215    2020-07-28 03:22:44  [('RT', 4.88), ('would', 5.38), ('destroy', 2....
# 250    2020-08-04 23:00:38  [('RT', 4.88), ('America', 6.76), ('President'...
# 343    2017-07-29 17:04:20  [('Stock', 5.8), ('Market', 6.28), ('almost', ...
# 475    2020-10-21 12:54:12  [('Remember', 6.42), ('going', 5.42), ('raise'...
# 501    2020-04-30 12:10:00  [('RT', 4.88), ('The', 4.98), ('economy', 4.38...
# ...                    ...                                                ...
# 54339  2019-01-09 14:06:09  [('Our', 6.08), ('Country', 6.28), ('well', 6....
# 54345  2019-01-08 13:01:15  [('Economic', 5.36), ('numbers', 6.04), ('look...
# 54376  2019-01-04 13:06:40  [('As', 5.22), ('I', 5.92), ('stated', 5.26), ...
# 54411  2020-01-09 02:54:59  [('STOCK', 5.8), ('MARKET', 6.28), ('AT', 4.9)...
# 54418  2020-01-04 22:16:27  [('As', 5.22), ('hard', 4.1), ('I', 5.92), ('w...
#
#                                              scores_only  avg_scores  \
# 215    [4.88, 5.38, 2.52, 6.74, 5.58, 2.7, 4.9, 5.22,...    4.998333
# 250                 [4.88, 6.76, 5.86, 5.28, 6.28, 4.38]    5.573333
# 343                         [5.8, 6.28, 4.7, 5.24, 5.18]    5.440000
# 475    [6.42, 5.42, 6.74, 2.7, 5.6, 3.34, 5.4, 5.06, ...    4.936923
# 501    [4.88, 4.98, 4.38, 5.42, 6.68, 6.4, 6.0, 5.3, ...    5.651667
# ...                                                  ...         ...
# 54339  [6.08, 6.28, 6.68, 5.82, 5.3, 7.88, 6.32, 6.04...    5.714194
# 54345  [5.36, 6.04, 5.94, 5.84, 7.2, 5.62, 7.18, 5.92...    5.663871
# 54376  [5.22, 5.92, 5.26, 5.82, 5.58, 5.5, 5.18, 6.34...    5.838182
# 54411  [5.8, 6.28, 4.9, 6.64, 4.68, 5.16, 5.6, 5.04, ...    5.205000
# 54418  [5.22, 4.1, 5.92, 5.24, 5.44, 8.16, 6.28, 5.7,...    5.691429
#
#        sum_scores sentiment_category  word_count  \
# 215         59.98           negative          68
# 250         33.44           positive          36
# 343         27.20            neutral          28
# 475         64.18           negative          75
# 501         67.82           positive          67
# ...           ...                ...         ...
# 54339      177.14           positive         183
# 54345      175.58           positive         184
# 54376      128.44           positive         126
# 54411       62.46            neutral          67
# 54418      159.36           positive         162
#
#                                                   tokens
# 215    [RT, @, realDonaldTrump, :, ...., would, destr...
# 250    [RT, @, LouDobbs, :, Reopening, America, :, Pr...
# 343    [U.S., Stock, Market, almost, 20, %, since, El...
# 475    [Remember, ,, BIDEN, going, raise, taxes, leve...
# 501    [RT, @, mitchellvii, :, The, economy, going, w...
# ...                                                  ...
# 54339  [Our, Country, well, many, ways, ., Great, job...
# 54345  [Economic, numbers, looking, REALLY, good, ., ...
# 54376  [As, I, stated, many, times, ,, Democrats, tak...
# 54411  [STOCK, MARKET, AT, ALL-TIME, HIGH, !, HOW, AR...
# 54418  [As, hard, I, work, ,, &, amp, ,, successful, ...
#
# [1219 rows x 15 columns]

# %% [markdown]
# ## The hedonometer word sentiment scores dataframe

# %%
print(hedo_df.head())
print(hedo_df.shape)
# Out:
#    Unnamed: 0  happs  rank  stdDev            word
# 0           0    5.1  6648    0.99       according
# 1           1    5.1  6649    1.58  administrative
# 2           2    5.1  6650    1.25          albert
# 3           3    5.1  6651    1.31          alleen
# 4           4    5.1  6652    1.30           allen
# (10187, 5)

# %% [markdown]
# ## Tokenize tweets and remove the stopwords to take away "filler" type words

# %%
# Use nltk for tokenizer and stopwords removal
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jaysu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jaysu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text_tokens=tweet_df['text'].apply(lambda x: word_tokenize(x))

# %%
# Notice the structure of the first tweet with "stopwords"
text_tokens[0]
# Out:
# ['Republicans',
#  'and',
#  'Democrats',
#  'have',
#  'both',
#  'created',
#  'our',
#  'economic',
#  'problems',
#  '.']

# %%
# Tokenize each tweet, remove stopwords, and append into a list to be added to dataframe later
tokens = []
# Cache the stopword function to speed up runtime. Otherwise the loop will access the method each iteration and slow down for loop. 
cachedStopWords = stopwords.words('english')
for tweet in tweet_df['text']:
    text_tokens = word_tokenize(tweet)
    token = [word for word in text_tokens if not word in cachedStopWords]
    tokens.append(token)
#     print(token)

# %%
# Inpsect list object for removal of stopwords
tokens[0]
# Out:
# ['Republicans', 'Democrats', 'created', 'economic', 'problems', '.']

# %% [markdown]
# ## Pull the score of each word in each Tweet. Make sure that the list structure is intact.

# %%
# Look through the tokens list and access the value of the word with .loc()
# Append words in a tweet list, then append that list to the scores list
# Make sure to turn all words into lowercase first to match the hedo_df words
word_and_scores = []
for token in tokens:
    tweet = []
    for word in token:
        score = hedo_df.loc[hedo_df['word'] == word.lower(), 'happs']
        if score.values.size:
            tweet.append((word, score.values[0]))
#             print(word,score.values[0])
    word_and_scores.append(tweet)

# %%
word_and_scores[0]
# Out:
# [('Republicans', 4.22),
#  ('Democrats', 5.5),
#  ('created', 6.06),
#  ('economic', 5.36),
#  ('problems', 2.92)]

# %%
# Populate only the scores of the individual words of each tweet in list of lists
scores_only = []
for token in tokens:
    tweet = []
    for word in token:
        score = hedo_df.loc[hedo_df['word'] == word.lower(), 'happs']
        if score.values.size:
            tweet.append(score.values[0])
#             print(score.values[0])
    scores_only.append(tweet)

# %%
scores_only[0]
# Out:
# [4.22, 5.5, 6.06, 5.36, 2.92]

# %% [markdown]
# ## Aggregation functions of the score list - sum and mean

# %%
# how to .agg() a new colum with mean and sum? 
import statistics as st
sum_scores = [sum(x) for x in scores_only]

# %%
sum_scores[:5]
# Out:
# [24.059999999999995,
#  142.1,
#  49.019999999999996,
#  147.05999999999997,
#  63.41999999999999]

# %%
# To calculate mean you must create a function with a try/except logic for 'nan' values
def check(data):
    try:
        return st.mean(data)
    except:
        return np.nan
avg_scores = [check(x) for x in scores_only]

# %%
avg_scores[:5]
# Out:
# [4.812, 6.459090909090909, 5.446666666666666, 4.902, 5.765454545454546]

# %% [markdown]
# ## Append the tweet dataframe with the new lists

# %%
# Inspect the DF with the newly added columns
tweet_df['word_and_scores'] = word_and_scores
tweet_df['scores_only'] = scores_only
tweet_df['avg_scores'] = avg_scores
tweet_df['sum_scores'] = sum_scores
tweet_df.head()
# Out:
#                     id                                               text  \
# 0    98454970654916608  Republicans and Democrats have both created ou...
# 1  1234653427789070336  I was thrilled to be back in the Great city of...
# 2  1218010753434820614  RT @CBS_Herridge: READ: Letter to surveillance...
# 3  1304875170860015617  The Unsolicited Mail In Ballot Scam is a major...
# 4  1218159531554897920  RT @MZHemingway: Very friendly telling of even...
#
#   isRetweet isDeleted              device  favorites  retweets  \
# 0         f         f           TweetDeck         49       255
# 1         f         f  Twitter for iPhone      73748     17404
# 2         t         f  Twitter for iPhone          0      7396
# 3         f         f  Twitter for iPhone      80527     23502
# 4         t         f  Twitter for iPhone          0      9081
#
#                   date                                    word_and_scores  \
# 0  2011-08-02 18:07:48  [(Republicans, 4.22), (Democrats, 5.5), (creat...
# 1  2020-03-03 01:34:50  [(I, 5.92), (back, 5.18), (Great, 7.88), (city...
# 2  2020-01-17 03:22:47  [(RT, 4.88), (READ, 6.52), (Letter, 5.94), (co...
# 3  2020-09-12 20:10:58  [(The, 4.98), (Mail, 6.36), (In, 5.5), (Ballot...
# 4  2020-01-17 13:13:59  [(RT, 4.88), (Very, 6.12), (friendly, 7.66), (...
#
#                                          scores_only  avg_scores  sum_scores
# 0                      [4.22, 5.5, 6.06, 5.36, 2.92]    4.812000       24.06
# 1  [5.92, 5.18, 7.88, 5.76, 5.5, 5.52, 5.44, 6.14...    6.459091      142.10
# 2  [4.88, 6.52, 5.94, 3.78, 6.36, 4.96, 5.6, 5.0,...    5.446667       49.02
# 3  [4.98, 6.36, 5.5, 5.16, 5.76, 2.36, 6.36, 5.44...    4.902000      147.06
# 4  [4.88, 6.12, 7.66, 5.3, 6.26, 4.94, 5.6, 5.62,...    5.765455       63.42

# %%
# Save the cleaned tweet_df as a .csv for rest of team to use
# tweet_df.to_csv('tweet_df_cleaned.csv')

# %%
# create new column
tweet_df_scores['sentiment_category'] = ''
tweet_df_scores['word_count']= ''
tweet_df_scores['word_count'] = tweet_df_scores['scores_only'].str.len()

# assign sentiment category
tweet_df_scores.loc[tweet_df_scores.avg_scores >= 5.5, 'sentiment_category'] = 'positive'
tweet_df_scores.loc[(tweet_df_scores.avg_scores > 5) & (tweet_df_scores.avg_scores < 5.5), 'sentiment_category'] = 'neutral'
tweet_df_scores.loc[tweet_df_scores.avg_scores <= 5 , 'sentiment_category'] = 'negative'

# %%
tweet_df_scores.head()
# Out:
#    Unnamed: 0                   id  \
# 0           0    98454970654916608
# 1           1  1234653427789070336
# 2           2  1218010753434820614
# 3           3  1304875170860015617
# 4           4  1218159531554897920
#
#                                                 text isRetweet isDeleted  \
# 0  Republicans and Democrats have both created ou...         f         f
# 1  I was thrilled to be back in the Great city of...         f         f
# 2  RT @CBS_Herridge: READ: Letter to surveillance...         t         f
# 3  The Unsolicited Mail In Ballot Scam is a major...         f         f
# 4  RT @MZHemingway: Very friendly telling of even...         t         f
#
#                device  favorites  retweets                 date  \
# 0           TweetDeck         49       255  2011-08-02 18:07:48
# 1  Twitter for iPhone      73748     17404  2020-03-03 01:34:50
# 2  Twitter for iPhone          0      7396  2020-01-17 03:22:47
# 3  Twitter for iPhone      80527     23502  2020-09-12 20:10:58
# 4  Twitter for iPhone          0      9081  2020-01-17 13:13:59
#
#                                      word_and_scores  \
# 0  [('Republicans', 4.22), ('Democrats', 5.5), ('...
# 1  [('I', 5.92), ('back', 5.18), ('Great', 7.88),...
# 2  [('RT', 4.88), ('READ', 6.52), ('Letter', 5.94...
# 3  [('The', 4.98), ('Mail', 6.36), ('In', 5.5), (...
# 4  [('RT', 4.88), ('Very', 6.12), ('friendly', 7....
#
#                                          scores_only  avg_scores  sum_scores  \
# 0                      [4.22, 5.5, 6.06, 5.36, 2.92]    4.812000       24.06
# 1  [5.92, 5.18, 7.88, 5.76, 5.5, 5.52, 5.44, 6.14...    6.459091      142.10
# 2  [4.88, 6.52, 5.94, 3.78, 6.36, 4.96, 5.6, 5.0,...    5.446667       49.02
# 3  [4.98, 6.36, 5.5, 5.16, 5.76, 2.36, 6.36, 5.44...    4.902000      147.06
# 4  [4.88, 6.12, 7.66, 5.3, 6.26, 4.94, 5.6, 5.62,...    5.765455       63.42
#
#   sentiment_category  word_count
# 0           negative          29
# 1           positive         129
# 2            neutral          52
# 3           negative         172
# 4           positive          64

# %%
# Save the cleaned tweet_df as a .csv for rest of team to use
tweet_df_scores.to_csv('tweet_df_cleaned_w_sentiment.csv')
